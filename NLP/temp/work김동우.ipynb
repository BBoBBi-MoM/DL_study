# %% [markdown]
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2F1nVj0%2FbtryniURChE%2FoHO5QsqWiaJNRPjDz3LgzK%2Fimg.png)

# %% [markdown]
# ---
# ### 데이터 불러오기
# ---

# %%
from konlpy.tag import Okt
from tqdm import tqdm
import pandas as pd
import numpy as np
from nltk import FreqDist

# %% [markdown]
# ---
# ### 수제함수
# ---

# %%
def select_stopword(vocab):
    stop_words = list()
    for word,_ in vocab:
        print(word,': 불용어에 포함시킬 단어면 y 아니면 n 입력, x입력시 취소')
        
        while True:
            input_value = input()
            if input_value in ['y','Y']:
                stop_words.append(word)
                break

            elif input_value in ['n','N']:
                break
            
            elif input_value in ['x','X']:
                return
            else:
                print('잘못된 입력입니다. 다시 입력하시오.')
                continue
    return stop_words

# %% [markdown]
# ---
# ### 데이터 확인
# ---

# %%
train_data = pd.read_table('./ratings_train.txt')
test_data = pd.read_table('./ratings_test.txt')

# %%
train_data.document = train_data.document.str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","",regex=True)  #한글을 제외한 단어는 정규식으로 제거

# %%
train_data['document'].isna().sum()   # 결측치의 수 확인
# Out:
# 5

# %%
train_data.dropna(inplace=True)   #결측치 제거

# %% [markdown]
# ---
# ### 토큰화
# ---

# %% [markdown]
# [불용어 모음 사이트1](https://www.ranks.nl/stopwords/korean)
# [불용어 모음 사이트2](https://bab2min.tistory.com/544)

# %%
stop_word_df1=pd.read_html('https://www.ranks.nl/stopwords/korean')[0]   #페이지의 테이블을 가져온다
stop_word_df2=pd.read_html('https://bab2min.tistory.com/544',encoding='utf-8')[0]

# %%
stop_words_list = stop_word_df2.iloc[:,[0,-3]].values.reshape(-1).tolist() # df.values <- 넘파이 배열로 바꿔줌. reshape(-1).1차원 배열로 바꿔줌. tolist() 배열을 리스트로 바꿔줌

# %%
for i in range(len(stop_word_df1)):
    words = stop_word_df1.iloc[0,i].split(' ')
    stop_words_list += words
    
stop_words_list += ['너무','다','적','진짜','에서','점','영화','정말','의','가',
                    '이','은','들','는','좀','잘','걍','과','도','를','으로','자',
                    '에','와','한','하다','것','그','안','인','이런','내','못','게',
                    '이다','고','더','때','거','요','본','지','네','입니다','있는',
                    '걸','이렇게','임','라','인데','듯','기','서','난','면','대','라고',
                    '보면','이나','때문','해서','된','엔','두','이고','랑','전','애',
                    '없이','해','속','한다','라는','뿐','되는','니','줄','냐','하게',
                    '하고','합니다','번','하지','보고']  # 수제 모음집

print('불용어 수:',len(stop_words_list))
# Out:
# 불용어 수: 463

# %%
tokenizer = Okt()   #토큰화에 필요한 Okt 클래스
tokenized = list()  #토큰화된 문장을 담을 리스트 생성
for sentence in tqdm(train_data.document):  # 리뷰 하나씩 꺼내오기. tqdm: iteration 1회에 걸린 시간으로 한 반복문에 걸리는 시간을 추론하여 진행상황을 알려줌
    if not isinstance(sentence,str):          # 이상한 값이 있으면 무시하고 공백 추가
        tokenized.append('')         
    tokenized_sentence = tokenizer.morphs(sentence)                   #문장을 토큰화 리스트 반환
    tokenized_sentence = [word for word in tokenized_sentence if not word in stop_words_list] # 불용어 리스트에 없는 단어만 남기기
    tokenized.append(tokenized_sentence)       #토큰화된 문장을 리스트에 추가

print(len(tokenized))
# Out:
# 100%|██████████| 149995/149995 [04:58<00:00, 502.38it/s]
# 149995

# %% [markdown]
# ---
# ### 단어 집합 생성
# ---

# %%
vocab = FreqDist(np.hstack(tokenized))    # 빈도수를 알아서 구해주는 함수와 클래스들
vocab_size = 5000                          # top 5000만 사용하기
vocab = vocab.most_common(vocab_size)     
print(f'단어 집합의 크기 : {len(vocab)}')
print('빈도수 상위 10선:',vocab[:10])
# Out:
# 단어 집합의 크기 : 5000
# 빈도수 상위 10선: [('연기', 6328), ('평점', 6315), ('최고', 6040), ('스토리', 5335), ('드라마', 5063), ('감동', 4881), ('ㅋㅋ', 4307), ('배우', 4292), ('감독', 4118), ('그냥', 4082)]

# %%
vocab
# Out:
# [('연기', 6328),
#  ('평점', 6315),
#  ('최고', 6040),
#  ('스토리', 5335),
#  ('드라마', 5063),
#  ('감동', 4881),
#  ('ㅋㅋ', 4307),
#  ('배우', 4292),
#  ('감독', 4118),
#  ('그냥', 4082),
#  ('재미', 3921),
#  ('내용', 3814),
#  ('뭐', 3800),
#  ('쓰레기', 3564),
#  ('보다', 3552),
#  ('없는', 3486),
#  ('봤는데', 3033),
#  ('작품', 2980),
#  ('사랑', 2943),
#  ('볼', 2830),
#  ('마지막', 2757),
#  ('좋은', 2663),
#  ('이건', 2605),
#  ('같은', 2554),
#  ('완전', 2540),
#  ('ㅋ', 2538),
#  ('ㅠㅠ', 2489),
#  ('ㅋㅋㅋ', 2461),
#  ('처음', 2453),
#  ('장면', 2425),
#  ('액션', 2397),
#  ('주인공', 2376),
#  ('보는', 2294),
#  ('최악', 2275),
#  ('돈', 2196),
#  ('이야기', 2174),
#  ('별로', 2132),
#  ('봐도', 2123),
#  ('느낌', 2102),
#  ('참', 2088),
#  ('ㅡㅡ', 2082),
#  ('연출', 2076),
#  ('없고', 2059),
#  ('명작', 2041),
#  ('끝', 2039),
#  ('역시', 1994),
#  ('별', 1934),
#  ('많이', 1933),
#  ('재밌게', 1913),
#  ('이해', 1898),
#  ('이영화', 1816),
#  ('분', 1807),
#  ('성', 1734),
#  ('아깝다', 1640),
#  ('꼭', 1629),
#  ('보기', 1613),
#  ('짱', 1598),
#  ('기억', 1592),
#  ('결말', 1580),
#  ('ㅎㅎ', 1573),
#  ('편', 1570),
#  ('같다', 1564),
#  ('마음', 1552),
#  ('인생', 1542),
#  ('영', 1512),
#  ('소재', 1508),
#  ('넘', 1496),
#  ('님', 1465),
#  ('수준', 1450),
#  ('현실', 1422),
#  ('한번', 1405),
#  ('가장', 1391),
#  ('급', 1376),
#  ('매력', 1372),
#  ('반전', 1367),
#  ('전개', 1361),
#  ('함', 1357),
#  ('한국', 1335),
#  ('남자', 1333),
#  ('가슴', 1331),
#  ('아이', 1306),
#  ('음악', 1277),
#  ('원작', 1253),
#  ('만든', 1236),
#  ('화', 1209),
#  ('인간', 1209),
#  ('추천', 1189),
#  ('눈물', 1182),
#  ('않고', 1180),
#  ('인지', 1174),
#  ('모든', 1167),
#  ('봤다', 1162),
#  ('자체', 1150),
#  ('눈', 1130),
#  ('인가', 1083),
#  ('캐릭터', 1075),
#  ('대박', 1072),
#  ('코미디', 1072),
#  ('처럼', 1065),
#  ('솔직히', 1064),
#  ('ㅋㅋㅋㅋ', 1062),
#  ('움', 1061),
#  ('좋다', 1056),
#  ('대한', 1055),
#  ('모두', 1049),
#  ('뭔가', 1047),
#  ('이상', 1047),
#  ('ㅠ', 1043),
#  ('했다', 1042),
#  ('이네', 1040),
#  ('전혀', 1039),
#  ('연기력', 1031),
#  ('여운', 1027),
#  ('개봉', 1010),
#  ('공감', 1003),
#  ('기대', 1002),
#  ('일본', 1000),
#  ('시리즈', 997),
#  ('있다', 995),
#  ('허', 994),
#  ('근데', 993),
#  ('중간', 992),
#  ('표현', 990),
#  ('굿', 990),
#  ('아주', 988),
#  ('영상', 988),
#  ('부분', 983),
#  ('모습', 975),
#  ('에는', 970),
#  ('이라', 969),
#  ('작', 962),
#  ('계속', 955),
#  ('제목', 955),
#  ('이랑', 952),
#  ('ㅜㅜ', 950),
#  ('재밌다', 946),
#  ('가족', 937),
#  ('내내', 933),
#  ('보지', 931),
#  ('뭔', 929),
#  ('봐', 917),
#  ('진심', 916),
#  ('재미있게', 916),
#  ('실망', 914),
#  ('없음', 911),
#  ('많은', 911),
#  ('하면', 910),
#  ('몰입', 907),
#  ('어떻게', 900),
#  ('후', 895),
#  ('ㅎ', 895),
#  ('나오는', 893),
#  ('였다', 891),
#  ('기분', 890),
#  ('했는데', 887),
#  ('연', 883),
#  ('봤습니다', 880),
#  ('작가', 879),
#  ('건', 878),
#  ('건지', 872),
#  ('이제', 867),
#  ('않은', 864),
#  ('보면서', 863),
#  ('위', 859),
#  ('요즘', 852),
#  ('잼', 849),
#  ('공포', 848),
#  ('스릴러', 845),
#  ('아니고', 845),
#  ('이라는', 843),
#  ('감', 842),
#  ('시', 840),
#  ('용', 839),
#  ('긴장감', 832),
#  ('개인', 830),
#  ('점도', 825),
#  ('재미없다', 821),
#  ('않는', 813),
#  ('알바', 802),
#  ('애니', 802),
#  ('대사', 801),
#  ('아닌', 800),
#  ('이유', 799),
#  ('특히', 797),
#  ('제대로', 796),
#  ('삶', 796),
#  ('아까운', 795),
#  ('극장', 794),
#  ('노래', 793),
#  ('노잼', 790),
#  ('한테', 788),
#  ('점수', 783),
#  ('욕', 780),
#  ('시작', 775),
#  ('보다가', 768),
#  ('막장', 767),
#  ('아름다운', 765),
#  ('이란', 763),
#  ('나름', 760),
#  ('오랜', 760),
#  ('재밌어요', 756),
#  ('극', 755),
#  ('이지', 753),
#  ('에도', 748),
#  ('제일', 747),
#  ('차라리', 744),
#  ('놈', 742),
#  ('친구', 736),
#  ('좋고', 736),
#  ('영화로', 732),
#  ('보게', 729),
#  ('당시', 729),
#  ('봤어요', 727),
#  ('같이', 725),
#  ('의미', 721),
#  ('절대', 718),
#  ('식', 713),
#  ('보세요', 713),
#  ('만드는', 711),
#  ('위해', 710),
#  ('있고', 708),
#  ('력', 708),
#  ('류', 706),
#  ('세상', 704),
#  ('싶다', 700),
#  ('뻔한', 699),
#  ('아직도', 697),
#  ('년대', 690),
#  ('이라고', 690),
#  ('해도', 689),
#  ('공포영화', 688),
#  ('미국', 687),
#  ('웃음', 684),
#  ('도대체', 683),
#  ('아무', 680),
#  ('설정', 679),
#  ('보니', 678),
#  ('무엇', 677),
#  ('마다', 675),
#  ('너', 671),
#  ('초반', 663),
#  ('물', 653),
#  ('뭘', 652),
#  ('나도', 651),
#  ('수작', 649),
#  ('좋아하는', 648),
#  ('출연', 648),
#  ('우리나라', 647),
#  ('봄', 646),
#  ('추억', 637),
#  ('엄청', 636),
#  ('주고', 634),
#  ('좋았다', 634),
#  ('안되는', 631),
#  ('남는', 631),
#  ('한국영', 629),
#  ('보는내내', 628),
#  ('지루함', 628),
#  ('남', 626),
#  ('반', 626),
#  ('준다', 622),
#  ('시나리오', 620),
#  ('주는', 620),
#  ('관객', 618),
#  ('이야', 618),
#  ('분위기', 617),
#  ('장난', 616),
#  ('팬', 614),
#  ('든', 611),
#  ('좋아요', 610),
#  ('시대', 610),
#  ('된다', 608),
#  ('지루하고', 606),
#  ('졸작', 604),
#  ('세', 602),
#  ('이딴', 598),
#  ('봤던', 597),
#  ('감정', 596),
#  ('최고다', 594),
#  ('같아요', 592),
#  ('준', 591),
#  ('엔딩', 588),
#  ('접', 588),
#  ('영화관', 587),
#  ('오늘', 585),
#  ('엄마', 585),
#  ('구', 583),
#  ('결국', 582),
#  ('제발', 581),
#  ('정신', 579),
#  ('인상', 577),
#  ('라면', 575),
#  ('더빙', 573),
#  ('포스터', 572),
#  ('캐스팅', 572),
#  ('평가', 569),
#  ('코믹', 568),
#  ('니까', 567),
#  ('아무리', 563),
#  ('될', 561),
#  ('엉', 559),
#  ('멋진', 556),
#  ('애니메이션', 555),
#  ('그저', 553),
#  ('함께', 553),
#  ('음', 549),
#  ('몰입도', 548),
#  ('신', 547),
#  ('괜찮은', 546),
#  ('킬링타임', 544),
#  ('어릴', 542),
#  ('티비', 542),
#  ('했던', 541),
#  ('봐서', 541),
#  ('기도', 538),
#  ('재밌음', 537),
#  ('배경', 537),
#  ('첨', 535),
#  ('뒤', 531),
#  ('맘', 530),
#  ('충격', 524),
#  ('스릴', 524),
#  ('전쟁', 520),
#  ('만화', 520),
#  ('얘기', 519),
#  ('존나', 518),
#  ('책', 517),
#  ('개연', 516),
#  ('건가', 515),
#  ('같은데', 515),
#  ('예술', 515),
#  ('간', 514),
#  ('싶은', 514),
#  ('머리', 514),
#  ('매우', 513),
#  ('머', 513),
#  ('갈수록', 512),
#  ('질', 512),
#  ('조', 511),
#  ('보단', 510),
#  ('웃기', 509),
#  ('얼굴', 509),
#  ('큰', 507),
#  ('후회', 507),
#  ('이름', 506),
#  ('재밌는', 506),
#  ('옛날', 505),
#  ('영화인', 505),
#  ('너무나', 504),
#  ('구성', 504),
#  ('나온', 502),
#  ('하면서', 500),
#  ('집중', 500),
#  ('이후', 496),
#  ('울', 496),
#  ('까', 494),
#  ('총', 493),
#  ('않는다', 492),
#  ('꽤', 491),
#  ('장르', 491),
#  ('지루한', 487),
#  ('만들어', 484),
#  ('날', 484),
#  ('봐라', 482),
#  ('주연', 481),
#  ('하는데', 480),
#  ('다큐', 475),
#  ('시즌', 475),
#  ('상황', 474),
#  ('누구', 474),
#  ('지루하다', 473),
#  ('모르겠다', 473),
#  ('재미없음', 473),
#  ('상', 471),
#  ('이리', 470),
#  ('씬', 467),
#  ('짜증', 466),
#  ('억지', 466),
#  ('예전', 463),
#  ('강추', 463),
#  ('글', 463),
#  ('아직', 462),
#  ('비', 462),
#  ('후반', 460),
#  ('역사', 460),
#  ('다운', 460),
#  ('보는데', 459),
#  ('어느', 458),
#  ('먹', 458),
#  ('걸작', 458),
#  ('아님', 455),
#  ('진', 455),
#  ('마세요', 453),
#  ('누가', 453),
#  ('했지만', 446),
#  ('자기', 446),
#  ('소름', 446),
#  ('만점', 444),
#  ('인물', 443),
#  ('실화', 443),
#  ('발연기', 442),
#  ('본다', 442),
#  ('그나마', 441),
#  ('그대로', 439),
#  ('방송', 439),
#  ('분들', 438),
#  ('시절', 436),
#  ('봤음', 435),
#  ('아까', 433),
#  ('회', 433),
#  ('비디오', 432),
#  ('대체', 431),
#  ('할수', 430),
#  ('없어', 428),
#  ('한마디', 427),
#  ('소설', 426),
#  ('재밌고', 426),
#  ('부', 426),
#  ('로맨스', 425),
#  ('봤지만', 425),
#  ('초딩', 424),
#  ('아들', 424),
#  ('비교', 423),
#  ('됨', 421),
#  ('감성', 420),
#  ('판', 420),
#  ('네이버', 420),
#  ('다음', 418),
#  ('여주', 416),
#  ('여배우', 415),
#  ('전체', 415),
#  ('나와서', 414),
#  ('이었다', 414),
#  ('간만', 414),
#  ('해야', 413),
#  ('죠', 411),
#  ('꿈', 410),
#  ('좋은데', 407),
#  ('장', 407),
#  ('라도', 406),
#  ('없네', 402),
#  ('같음', 402),
#  ('나이', 401),
#  ('이라도', 400),
#  ('성룡', 400),
#  ('코', 398),
#  ('나라', 398),
#  ('재', 398),
#  ('였습니다', 396),
#  ('재밋', 395),
#  ('동안', 394),
#  ('혼자', 392),
#  ('어렸을', 392),
#  ('열', 392),
#  ('삼류', 391),
#  ('없어서', 390),
#  ('순간', 389),
#  ('교훈', 388),
#  ('쯤', 388),
#  ('보다는', 388),
#  ('아쉽다', 388),
#  ('재미있어요', 387),
#  ('ㅉㅉ', 386),
#  ('없었다', 386),
#  ('빨리', 385),
#  ('그만', 384),
#  ('가는', 384),
#  ('존재', 384),
#  ('힘', 382),
#  ('바로', 380),
#  ('미친', 380),
#  ('하네요', 380),
#  ('주제', 378),
#  ('어설픈', 378),
#  ('낸', 378),
#  ('목소리', 375),
#  ('낭비', 375),
#  ('에요', 375),
#  ('년도', 373),
#  ('억', 373),
#  ('진정한', 371),
#  ('죽', 370),
#  ('짜리', 369),
#  ('당신', 368),
#  ('는데', 366),
#  ('안보', 365),
#  ('몇번', 364),
#  ('질질', 362),
#  ('년전', 361),
#  ('굳', 361),
#  ('라니', 360),
#  ('잔잔한', 358),
#  ('말고', 358),
#  ('줄거리', 358),
#  ('상당히', 356),
#  ('재미있다', 355),
#  ('판타지', 354),
#  ('ㅜ', 354),
#  ('의도', 354),
#  ('에선', 353),
#  ('딸', 353),
#  ('이번', 353),
#  ('갑자기', 353),
#  ('아버지', 353),
#  ('좀비', 353),
#  ('좋아', 352),
#  ('있지만', 352),
#  ('보여주는', 351),
#  ('어른', 350),
#  ('되고', 349),
#  ('전부', 348),
#  ('피', 348),
#  ('재밌네요', 347),
#  ('점주', 347),
#  ('당', 347),
#  ('상영', 346),
#  ('모', 344),
#  ('시청률', 344),
#  ('ㅎㅎㅎ', 344),
#  ('실제', 344),
#  ('소', 343),
#  ('믿고', 343),
#  ('있을까', 342),
#  ('만하', 342),
#  ('ㅡ', 341),
#  ('하며', 341),
#  ('으로도', 341),
#  ('봤네요', 340),
#  ('평론가', 340),
#  ('곳', 339),
#  ('맛', 338),
#  ('점점', 338),
#  ('필요', 337),
#  ('땜', 336),
#  ('비해', 336),
#  ('단', 335),
#  ('재미있는', 334),
#  ('난다', 334),
#  ('버린', 334),
#  ('쳐', 334),
#  ('막', 333),
#  ('한편', 333),
#  ('히', 333),
#  ('제작', 333),
#  ('화면', 333),
#  ('사', 332),
#  ('바', 332),
#  ('같네요', 332),
#  ('대로', 332),
#  ('극장판', 331),
#  ('초', 330),
#  ('평', 330),
#  ('간다', 327),
#  ('답', 327),
#  ('중국', 327),
#  ('형', 327),
#  ('하네', 327),
#  ('있는데', 326),
#  ('있어', 326),
#  ('온', 326),
#  ('되지', 326),
#  ('각본', 326),
#  ('에서도', 325),
#  ('래', 325),
#  ('밑', 325),
#  ('나온다', 324),
#  ('볼때', 324),
#  ('굉장히', 324),
#  ('이하', 324),
#  ('훌륭한', 323),
#  ('있어서', 323),
#  ('관람', 322),
#  ('란', 321),
#  ('저런', 321),
#  ('선', 321),
#  ('스타일', 321),
#  ('올', 320),
#  ('일단', 320),
#  ('세계', 320),
#  ('가치', 320),
#  ('참고', 320),
#  ('선택', 320),
#  ('좋네요', 320),
#  ('성우', 319),
#  ('똥', 318),
#  ('요소', 318),
#  ('항상', 318),
#  ('터', 317),
#  ('둘', 317),
#  ('그런지', 317),
#  ('복수', 317),
#  ('봐야', 316),
#  ('어디서', 315),
#  ('햇', 315),
#  ('에서는', 314),
#  ('뻔', 312),
#  ('첫', 312),
#  ('흥행', 311),
#  ('해주는', 311),
#  ('어린', 311),
#  ('모르고', 310),
#  ('그때', 310),
#  ('드', 310),
#  ('여러', 310),
#  ('더욱', 309),
#  ('치고', 308),
#  ('없네요', 308),
#  ('진행', 307),
#  ('였음', 305),
#  ('슬픈', 305),
#  ('라서', 305),
#  ('이냐', 305),
#  ('좋음', 304),
#  ('인거', 302),
#  ('거기', 302),
#  ('아빠', 302),
#  ('씩', 301),
#  ('수가', 301),
#  ('역대', 301),
#  ('발', 300),
#  ('보는게', 300),
#  ('ㅋㅋㅋㅋㅋ', 299),
#  ('완성', 299),
#  ('전형', 299),
#  ('편집', 299),
#  ('멜로', 298),
#  ('했음', 298),
#  ('재미없는', 298),
#  ('상미', 298),
#  ('화이팅', 297),
#  ('새끼', 296),
#  ('충분히', 295),
#  ('더럽게', 295),
#  ('짓', 295),
#  ('이에요', 295),
#  ('해준', 294),
#  ('ㅠㅠㅠ', 294),
#  ('새로운', 293),
#  ('술', 293),
#  ('역', 293),
#  ('불륜', 292),
#  ('군', 292),
#  ('귀', 292),
#  ('알았는데', 290),
#  ('병맛', 290),
#  ('개그', 289),
#  ('일이', 289),
#  ('에겐', 289),
#  ('엉망', 288),
#  ('사건', 288),
#  ('거지', 288),
#  ('예상', 288),
#  ('잠', 287),
#  ('미화', 286),
#  ('중반', 285),
#  ('설명', 285),
#  ('꿀잼', 285),
#  ('그게', 284),
#  ('어쩔', 283),
#  ('과거', 283),
#  ('있음', 281),
#  ('프랑스', 280),
#  ('화보', 279),
#  ('키', 279),
#  ('좋겠다', 279),
#  ('따', 279),
#  ('나옴', 278),
#  ('흥미진진', 278),
#  ('도저히', 278),
#  ('손', 277),
#  ('재밌는데', 277),
#  ('노력', 277),
#  ('댓글', 276),
#  ('깊은', 276),
#  ('그래픽', 276),
#  ('여서', 276),
#  ('죽음', 276),
#  ('흥미', 275),
#  ('거리', 275),
#  ('같아', 275),
#  ('척', 275),
#  ('나올', 275),
#  ('무조건', 275),
#  ('취향', 274),
#  ('였어요', 274),
#  ('티', 274),
#  ('원래', 274),
#  ('몸', 274),
#  ('나오고', 273),
#  ('있게', 273),
#  ('않음', 273),
#  ('리', 273),
#  ('화가', 272),
#  ('한다는', 272),
#  ('새', 272),
#  ('따뜻한', 271),
#  ('하는게', 271),
#  ('알았다', 271),
#  ('배', 271),
#  ('현', 270),
#  ('자극', 270),
#  ('대단한', 269),
#  ('감상', 269),
#  ('암', 268),
#  ('며', 268),
#  ('만으로도', 267),
#  ('예', 265),
#  ('학교', 265),
#  ('아까워', 264),
#  ('괜히', 264),
#  ('자꾸', 263),
#  ('같습니다', 263),
#  ('액션영화', 263),
#  ('무', 263),
#  ('관', 262),
#  ('예고편', 262),
#  ('오히려', 262),
#  ('좋았어요', 261),
#  ('바보', 260),
#  ('결혼', 260),
#  ('이라니', 259),
#  ('다가', 259),
#  ('아저씨', 259),
#  ('엄청난', 259),
#  ('아닌가', 259),
#  ('심리', 259),
#  ('게임', 258),
#  ('이래', 258),
#  ('속편', 258),
#  ('재밌었다', 258),
#  ('꺼', 257),
#  ('용도', 257),
#  ('기대하고', 257),
#  ('흠', 256),
#  ('미', 255),
#  ('연기자', 255),
#  ('안됨', 255),
#  ('잘만', 255),
#  ('마무리', 255),
#  ('있을', 254),
#  ('관계', 253),
#  ('맨', 253),
#  ('양', 253),
#  ('천재', 252),
#  ('법', 252),
#  ('땐', 251),
#  ('야할', 251),
#  ('ㄷㄷ', 251),
#  ('억지로', 251),
#  ('표정', 251),
#  ('귀신', 250),
#  ('봤을', 250),
#  ('전설', 250),
#  ('영환', 250),
#  ('순', 249),
#  ('최근', 249),
#  ('유치', 249),
#  ('느끼게', 249),
#  ('높은', 248),
#  ('현재', 248),
#  ('헐', 247),
#  ('상상', 247),
#  ('나쁜', 247),
#  ('동', 247),
#  ('드는', 246),
#  ('타임', 246),
#  ('지루', 246),
#  ('젠', 245),
#  ('촬영', 245),
#  ('아쉬움', 245),
#  ('봣', 245),
#  ('오빠', 245),
#  ('대한민국', 244),
#  ('하는지', 244),
#  ('오래', 244),
#  ('완벽한', 244),
#  ('산', 243),
#  ('대작', 243),
#  ('짐', 243),
#  ('조차', 242),
#  ('재미있고', 242),
#  ('길', 242),
#  ('우연히', 241),
#  ('엇', 241),
#  ('전편', 241),
#  ('짜', 240),
#  ('스타', 240),
#  ('묘사', 239),
#  ('재미없고', 239),
#  ('메세지', 239),
#  ('만의', 239),
#  ('철학', 239),
#  ('하는거', 239),
#  ('일까', 238),
#  ('타', 238),
#  ('프로그램', 238),
#  ('마', 237),
#  ('동화', 237),
#  ('살다', 237),
#  ('프로', 236),
#  ('그림', 236),
#  ('만에', 234),
#  ('있었다', 234),
#  ('그렇고', 233),
#  ('예요', 232),
#  ('전달', 232),
#  ('서로', 232),
#  ('유머', 232),
#  ('유치한', 232),
#  ('공', 232),
#  ('졸라', 232),
#  ('역할', 231),
#  ('지루하지', 231),
#  ('무비', 231),
#  ('등장', 231),
#  ('쓴', 230),
#  ('조연', 230),
#  ('전작', 230),
#  ('경찰', 230),
#  ('스러운', 229),
#  ('다행', 229),
#  ('소녀', 229),
#  ('이미', 229),
#  ('먼저', 229),
#  ('나중', 228),
#  ('볼수', 228),
#  ('했으면', 227),
#  ('살인', 227),
#  ('먹고', 227),
#  ('마치', 227),
#  ('모르는', 227),
#  ('받아', 225),
#  ('아쉬운', 225),
#  ('특유', 224),
#  ('힘든', 224),
#  ('유치하고', 224),
#  ('재미없어', 224),
#  ('관심', 224),
#  ('되었다', 224),
#  ('비슷한', 223),
#  ('이며', 223),
#  ('보이는', 223),
#  ('사이', 222),
#  ('재밌었어요', 222),
#  ('지난', 222),
#  ('놔', 222),
#  ('행동', 222),
#  ('재밌어', 222),
#  ('환상', 222),
#  ('아닐까', 221),
#  ('통해', 221),
#  ('인정', 221),
#  ('아니지만', 220),
#  ('런가', 220),
#  ('노출', 220),
#  ('주의', 220),
#  ('노', 219),
#  ('왕', 219),
#  ('맞는', 219),
#  ('바람', 219),
#  ('청춘', 218),
#  ('지루해', 218),
#  ('않았다', 218),
#  ('미래', 218),
#  ('낚', 218),
#  ('입', 218),
#  ('예산', 217),
#  ('군대', 217),
#  ('정', 217),
#  ('리메이크', 217),
#  ('안나', 216),
#  ('하냐', 216),
#  ('만들지', 216),
#  ('깊이', 215),
#  ('같아서', 215),
#  ('안되고', 215),
#  ('망작', 215),
#  ('희망', 215),
#  ('ㅇ', 214),
#  ('보시길', 214),
#  ('비추', 213),
#  ('그닥', 213),
#  ('좋았음', 212),
#  ('제작비', 212),
#  ('감사합니다', 212),
#  ('께', 212),
#  ('ㅅㅂ', 212),
#  ('느낄', 211),
#  ('효과', 211),
#  ('재미있음', 211),
#  ('생애', 210),
#  ('영웅', 210),
#  ('좋았습니다', 210),
#  ('봤으면', 210),
#  ('왠지', 209),
#  ('으', 208),
#  ('화려한', 208),
#  ('해요', 208),
#  ('손발', 208),
#  ('진부한', 208),
#  ('외', 208),
#  ('보고나서', 208),
#  ('엿', 207),
#  ('돼', 207),
#  ('시도', 207),
#  ('필요없다', 207),
#  ('과정', 207),
#  ('보고싶다', 207),
#  ('너무나도', 206),
#  ('반개', 206),
#  ('용이', 206),
#  ('케이블', 206),
#  ('평생', 206),
#  ('긴', 206),
#  ('아닌데', 205),
#  ('나왔으면', 205),
#  ('좋았고', 205),
#  ('범인', 205),
#  ('형님', 204),
#  ('채널', 204),
#  ('봤었는데', 204),
#  ('있나', 203),
#  ('ㅇㅇ', 203),
#  ('미소', 203),
#  ('이런거', 203),
#  ('잘못', 203),
#  ('이상한', 203),
#  ('능력', 203),
#  ('얼', 203),
#  ('싫다', 203),
#  ('생', 202),
#  ('가끔', 202),
#  ('만들었다', 202),
#  ('강', 202),
#  ('였는데', 201),
#  ('상상력', 201),
#  ('버렸다', 201),
#  ('좋았는데', 201),
#  ('약', 201),
#  ('빼고', 201),
#  ('스케일', 201),
#  ('대단하다', 200),
#  ('카메라', 200),
#  ('기세', 200),
#  ('이런게', 200),
#  ('존', 200),
#  ('결론', 200),
#  ('그리', 199),
#  ('없을', 199),
#  ('광고', 198),
#  ('나와', 198),
#  ('않게', 198),
#  ('독립영화', 198),
#  ('그래', 198),
#  ('저렇게', 198),
#  ('의리', 198),
#  ('체', 198),
#  ('대충', 198),
#  ('계', 197),
#  ('확실히', 197),
#  ('자막', 196),
#  ('메시지', 196),
#  ('낮은', 196),
#  ('언니', 195),
#  ('대안', 195),
#  ('한계', 195),
#  ('있다면', 195),
#  ('줌', 195),
#  ('드립니다', 195),
#  ('부족', 195),
#  ('고민', 194),
#  ('부족한', 194),
#  ('고생', 194),
#  ('어이없는', 193),
#  ('짱짱', 193),
#  ('슬픔', 193),
#  ('여성', 193),
#  ('되게', 193),
#  ('나를', 192),
#  ('없나', 192),
#  ('들어', 192),
#  ('으로는', 192),
#  ('메디', 192),
#  ('봤다가', 192),
#  ('보고싶은', 191),
#  ('무서운', 191),
#  ('않아', 191),
#  ('있다는', 190),
#  ('리얼', 190),
#  ('없지만', 190),
#  ('볼수록', 190),
#  ('커플', 190),
#  ('유쾌한', 190),
#  ('든다', 189),
#  ('차', 189),
#  ('귀여운', 189),
#  ('슬프다', 189),
#  ('박수', 189),
#  ('동생', 189),
#  ('이면', 189),
#  ...]

# %% [markdown]
# ---
# ### 인코딩
# ---

# %%
word_to_id = {word[0] : id + 2 for id, word in enumerate(vocab)}
word_to_id['pad'] = 1 
word_to_id['unk'] = 0

encoded = []
for line in tokenized:
    temp = []
    for word in line: 
      try:
        temp.append(word_to_id[word]) 
      except: 
        temp.append(word_to_id['unk'])

    encoded.append(temp)
word_to_id
# Out:
# {'연기': 2,
#  '평점': 3,
#  '최고': 4,
#  '스토리': 5,
#  '드라마': 6,
#  '감동': 7,
#  'ㅋㅋ': 8,
#  '배우': 9,
#  '감독': 10,
#  '그냥': 11,
#  '재미': 12,
#  '내용': 13,
#  '뭐': 14,
#  '쓰레기': 15,
#  '보다': 16,
#  '없는': 17,
#  '봤는데': 18,
#  '작품': 19,
#  '사랑': 20,
#  '볼': 21,
#  '마지막': 22,
#  '좋은': 23,
#  '이건': 24,
#  '같은': 25,
#  '완전': 26,
#  'ㅋ': 27,
#  'ㅠㅠ': 28,
#  'ㅋㅋㅋ': 29,
#  '처음': 30,
#  '장면': 31,
#  '액션': 32,
#  '주인공': 33,
#  '보는': 34,
#  '최악': 35,
#  '돈': 36,
#  '이야기': 37,
#  '별로': 38,
#  '봐도': 39,
#  '느낌': 40,
#  '참': 41,
#  'ㅡㅡ': 42,
#  '연출': 43,
#  '없고': 44,
#  '명작': 45,
#  '끝': 46,
#  '역시': 47,
#  '별': 48,
#  '많이': 49,
#  '재밌게': 50,
#  '이해': 51,
#  '이영화': 52,
#  '분': 53,
#  '성': 54,
#  '아깝다': 55,
#  '꼭': 56,
#  '보기': 57,
#  '짱': 58,
#  '기억': 59,
#  '결말': 60,
#  'ㅎㅎ': 61,
#  '편': 62,
#  '같다': 63,
#  '마음': 64,
#  '인생': 65,
#  '영': 66,
#  '소재': 67,
#  '넘': 68,
#  '님': 69,
#  '수준': 70,
#  '현실': 71,
#  '한번': 72,
#  '가장': 73,
#  '급': 74,
#  '매력': 75,
#  '반전': 76,
#  '전개': 77,
#  '함': 78,
#  '한국': 79,
#  '남자': 80,
#  '가슴': 81,
#  '아이': 82,
#  '음악': 83,
#  '원작': 84,
#  '만든': 85,
#  '화': 86,
#  '인간': 87,
#  '추천': 88,
#  '눈물': 89,
#  '않고': 90,
#  '인지': 91,
#  '모든': 92,
#  '봤다': 93,
#  '자체': 94,
#  '눈': 95,
#  '인가': 96,
#  '캐릭터': 97,
#  '대박': 98,
#  '코미디': 99,
#  '처럼': 100,
#  '솔직히': 101,
#  'ㅋㅋㅋㅋ': 102,
#  '움': 103,
#  '좋다': 104,
#  '대한': 105,
#  '모두': 106,
#  '뭔가': 107,
#  '이상': 108,
#  'ㅠ': 109,
#  '했다': 110,
#  '이네': 111,
#  '전혀': 112,
#  '연기력': 113,
#  '여운': 114,
#  '개봉': 115,
#  '공감': 116,
#  '기대': 117,
#  '일본': 118,
#  '시리즈': 119,
#  '있다': 120,
#  '허': 121,
#  '근데': 122,
#  '중간': 123,
#  '표현': 124,
#  '굿': 125,
#  '아주': 126,
#  '영상': 127,
#  '부분': 128,
#  '모습': 129,
#  '에는': 130,
#  '이라': 131,
#  '작': 132,
#  '계속': 133,
#  '제목': 134,
#  '이랑': 135,
#  'ㅜㅜ': 136,
#  '재밌다': 137,
#  '가족': 138,
#  '내내': 139,
#  '보지': 140,
#  '뭔': 141,
#  '봐': 142,
#  '진심': 143,
#  '재미있게': 144,
#  '실망': 145,
#  '없음': 146,
#  '많은': 147,
#  '하면': 148,
#  '몰입': 149,
#  '어떻게': 150,
#  '후': 151,
#  'ㅎ': 152,
#  '나오는': 153,
#  '였다': 154,
#  '기분': 155,
#  '했는데': 156,
#  '연': 157,
#  '봤습니다': 158,
#  '작가': 159,
#  '건': 160,
#  '건지': 161,
#  '이제': 162,
#  '않은': 163,
#  '보면서': 164,
#  '위': 165,
#  '요즘': 166,
#  '잼': 167,
#  '공포': 168,
#  '스릴러': 169,
#  '아니고': 170,
#  '이라는': 171,
#  '감': 172,
#  '시': 173,
#  '용': 174,
#  '긴장감': 175,
#  '개인': 176,
#  '점도': 177,
#  '재미없다': 178,
#  '않는': 179,
#  '알바': 180,
#  '애니': 181,
#  '대사': 182,
#  '아닌': 183,
#  '이유': 184,
#  '특히': 185,
#  '제대로': 186,
#  '삶': 187,
#  '아까운': 188,
#  '극장': 189,
#  '노래': 190,
#  '노잼': 191,
#  '한테': 192,
#  '점수': 193,
#  '욕': 194,
#  '시작': 195,
#  '보다가': 196,
#  '막장': 197,
#  '아름다운': 198,
#  '이란': 199,
#  '나름': 200,
#  '오랜': 201,
#  '재밌어요': 202,
#  '극': 203,
#  '이지': 204,
#  '에도': 205,
#  '제일': 206,
#  '차라리': 207,
#  '놈': 208,
#  '친구': 209,
#  '좋고': 210,
#  '영화로': 211,
#  '보게': 212,
#  '당시': 213,
#  '봤어요': 214,
#  '같이': 215,
#  '의미': 216,
#  '절대': 217,
#  '식': 218,
#  '보세요': 219,
#  '만드는': 220,
#  '위해': 221,
#  '있고': 222,
#  '력': 223,
#  '류': 224,
#  '세상': 225,
#  '싶다': 226,
#  '뻔한': 227,
#  '아직도': 228,
#  '년대': 229,
#  '이라고': 230,
#  '해도': 231,
#  '공포영화': 232,
#  '미국': 233,
#  '웃음': 234,
#  '도대체': 235,
#  '아무': 236,
#  '설정': 237,
#  '보니': 238,
#  '무엇': 239,
#  '마다': 240,
#  '너': 241,
#  '초반': 242,
#  '물': 243,
#  '뭘': 244,
#  '나도': 245,
#  '수작': 246,
#  '좋아하는': 247,
#  '출연': 248,
#  '우리나라': 249,
#  '봄': 250,
#  '추억': 251,
#  '엄청': 252,
#  '주고': 253,
#  '좋았다': 254,
#  '안되는': 255,
#  '남는': 256,
#  '한국영': 257,
#  '보는내내': 258,
#  '지루함': 259,
#  '남': 260,
#  '반': 261,
#  '준다': 262,
#  '시나리오': 263,
#  '주는': 264,
#  '관객': 265,
#  '이야': 266,
#  '분위기': 267,
#  '장난': 268,
#  '팬': 269,
#  '든': 270,
#  '좋아요': 271,
#  '시대': 272,
#  '된다': 273,
#  '지루하고': 274,
#  '졸작': 275,
#  '세': 276,
#  '이딴': 277,
#  '봤던': 278,
#  '감정': 279,
#  '최고다': 280,
#  '같아요': 281,
#  '준': 282,
#  '엔딩': 283,
#  '접': 284,
#  '영화관': 285,
#  '오늘': 286,
#  '엄마': 287,
#  '구': 288,
#  '결국': 289,
#  '제발': 290,
#  '정신': 291,
#  '인상': 292,
#  '라면': 293,
#  '더빙': 294,
#  '포스터': 295,
#  '캐스팅': 296,
#  '평가': 297,
#  '코믹': 298,
#  '니까': 299,
#  '아무리': 300,
#  '될': 301,
#  '엉': 302,
#  '멋진': 303,
#  '애니메이션': 304,
#  '그저': 305,
#  '함께': 306,
#  '음': 307,
#  '몰입도': 308,
#  '신': 309,
#  '괜찮은': 310,
#  '킬링타임': 311,
#  '어릴': 312,
#  '티비': 313,
#  '했던': 314,
#  '봐서': 315,
#  '기도': 316,
#  '재밌음': 317,
#  '배경': 318,
#  '첨': 319,
#  '뒤': 320,
#  '맘': 321,
#  '충격': 322,
#  '스릴': 323,
#  '전쟁': 324,
#  '만화': 325,
#  '얘기': 326,
#  '존나': 327,
#  '책': 328,
#  '개연': 329,
#  '건가': 330,
#  '같은데': 331,
#  '예술': 332,
#  '간': 333,
#  '싶은': 334,
#  '머리': 335,
#  '매우': 336,
#  '머': 337,
#  '갈수록': 338,
#  '질': 339,
#  '조': 340,
#  '보단': 341,
#  '웃기': 342,
#  '얼굴': 343,
#  '큰': 344,
#  '후회': 345,
#  '이름': 346,
#  '재밌는': 347,
#  '옛날': 348,
#  '영화인': 349,
#  '너무나': 350,
#  '구성': 351,
#  '나온': 352,
#  '하면서': 353,
#  '집중': 354,
#  '이후': 355,
#  '울': 356,
#  '까': 357,
#  '총': 358,
#  '않는다': 359,
#  '꽤': 360,
#  '장르': 361,
#  '지루한': 362,
#  '만들어': 363,
#  '날': 364,
#  '봐라': 365,
#  '주연': 366,
#  '하는데': 367,
#  '다큐': 368,
#  '시즌': 369,
#  '상황': 370,
#  '누구': 371,
#  '지루하다': 372,
#  '모르겠다': 373,
#  '재미없음': 374,
#  '상': 375,
#  '이리': 376,
#  '씬': 377,
#  '짜증': 378,
#  '억지': 379,
#  '예전': 380,
#  '강추': 381,
#  '글': 382,
#  '아직': 383,
#  '비': 384,
#  '후반': 385,
#  '역사': 386,
#  '다운': 387,
#  '보는데': 388,
#  '어느': 389,
#  '먹': 390,
#  '걸작': 391,
#  '아님': 392,
#  '진': 393,
#  '마세요': 394,
#  '누가': 395,
#  '했지만': 396,
#  '자기': 397,
#  '소름': 398,
#  '만점': 399,
#  '인물': 400,
#  '실화': 401,
#  '발연기': 402,
#  '본다': 403,
#  '그나마': 404,
#  '그대로': 405,
#  '방송': 406,
#  '분들': 407,
#  '시절': 408,
#  '봤음': 409,
#  '아까': 410,
#  '회': 411,
#  '비디오': 412,
#  '대체': 413,
#  '할수': 414,
#  '없어': 415,
#  '한마디': 416,
#  '소설': 417,
#  '재밌고': 418,
#  '부': 419,
#  '로맨스': 420,
#  '봤지만': 421,
#  '초딩': 422,
#  '아들': 423,
#  '비교': 424,
#  '됨': 425,
#  '감성': 426,
#  '판': 427,
#  '네이버': 428,
#  '다음': 429,
#  '여주': 430,
#  '여배우': 431,
#  '전체': 432,
#  '나와서': 433,
#  '이었다': 434,
#  '간만': 435,
#  '해야': 436,
#  '죠': 437,
#  '꿈': 438,
#  '좋은데': 439,
#  '장': 440,
#  '라도': 441,
#  '없네': 442,
#  '같음': 443,
#  '나이': 444,
#  '이라도': 445,
#  '성룡': 446,
#  '코': 447,
#  '나라': 448,
#  '재': 449,
#  '였습니다': 450,
#  '재밋': 451,
#  '동안': 452,
#  '혼자': 453,
#  '어렸을': 454,
#  '열': 455,
#  '삼류': 456,
#  '없어서': 457,
#  '순간': 458,
#  '교훈': 459,
#  '쯤': 460,
#  '보다는': 461,
#  '아쉽다': 462,
#  '재미있어요': 463,
#  'ㅉㅉ': 464,
#  '없었다': 465,
#  '빨리': 466,
#  '그만': 467,
#  '가는': 468,
#  '존재': 469,
#  '힘': 470,
#  '바로': 471,
#  '미친': 472,
#  '하네요': 473,
#  '주제': 474,
#  '어설픈': 475,
#  '낸': 476,
#  '목소리': 477,
#  '낭비': 478,
#  '에요': 479,
#  '년도': 480,
#  '억': 481,
#  '진정한': 482,
#  '죽': 483,
#  '짜리': 484,
#  '당신': 485,
#  '는데': 486,
#  '안보': 487,
#  '몇번': 488,
#  '질질': 489,
#  '년전': 490,
#  '굳': 491,
#  '라니': 492,
#  '잔잔한': 493,
#  '말고': 494,
#  '줄거리': 495,
#  '상당히': 496,
#  '재미있다': 497,
#  '판타지': 498,
#  'ㅜ': 499,
#  '의도': 500,
#  '에선': 501,
#  '딸': 502,
#  '이번': 503,
#  '갑자기': 504,
#  '아버지': 505,
#  '좀비': 506,
#  '좋아': 507,
#  '있지만': 508,
#  '보여주는': 509,
#  '어른': 510,
#  '되고': 511,
#  '전부': 512,
#  '피': 513,
#  '재밌네요': 514,
#  '점주': 515,
#  '당': 516,
#  '상영': 517,
#  '모': 518,
#  '시청률': 519,
#  'ㅎㅎㅎ': 520,
#  '실제': 521,
#  '소': 522,
#  '믿고': 523,
#  '있을까': 524,
#  '만하': 525,
#  'ㅡ': 526,
#  '하며': 527,
#  '으로도': 528,
#  '봤네요': 529,
#  '평론가': 530,
#  '곳': 531,
#  '맛': 532,
#  '점점': 533,
#  '필요': 534,
#  '땜': 535,
#  '비해': 536,
#  '단': 537,
#  '재미있는': 538,
#  '난다': 539,
#  '버린': 540,
#  '쳐': 541,
#  '막': 542,
#  '한편': 543,
#  '히': 544,
#  '제작': 545,
#  '화면': 546,
#  '사': 547,
#  '바': 548,
#  '같네요': 549,
#  '대로': 550,
#  '극장판': 551,
#  '초': 552,
#  '평': 553,
#  '간다': 554,
#  '답': 555,
#  '중국': 556,
#  '형': 557,
#  '하네': 558,
#  '있는데': 559,
#  '있어': 560,
#  '온': 561,
#  '되지': 562,
#  '각본': 563,
#  '에서도': 564,
#  '래': 565,
#  '밑': 566,
#  '나온다': 567,
#  '볼때': 568,
#  '굉장히': 569,
#  '이하': 570,
#  '훌륭한': 571,
#  '있어서': 572,
#  '관람': 573,
#  '란': 574,
#  '저런': 575,
#  '선': 576,
#  '스타일': 577,
#  '올': 578,
#  '일단': 579,
#  '세계': 580,
#  '가치': 581,
#  '참고': 582,
#  '선택': 583,
#  '좋네요': 584,
#  '성우': 585,
#  '똥': 586,
#  '요소': 587,
#  '항상': 588,
#  '터': 589,
#  '둘': 590,
#  '그런지': 591,
#  '복수': 592,
#  '봐야': 593,
#  '어디서': 594,
#  '햇': 595,
#  '에서는': 596,
#  '뻔': 597,
#  '첫': 598,
#  '흥행': 599,
#  '해주는': 600,
#  '어린': 601,
#  '모르고': 602,
#  '그때': 603,
#  '드': 604,
#  '여러': 605,
#  '더욱': 606,
#  '치고': 607,
#  '없네요': 608,
#  '진행': 609,
#  '였음': 610,
#  '슬픈': 611,
#  '라서': 612,
#  '이냐': 613,
#  '좋음': 614,
#  '인거': 615,
#  '거기': 616,
#  '아빠': 617,
#  '씩': 618,
#  '수가': 619,
#  '역대': 620,
#  '발': 621,
#  '보는게': 622,
#  'ㅋㅋㅋㅋㅋ': 623,
#  '완성': 624,
#  '전형': 625,
#  '편집': 626,
#  '멜로': 627,
#  '했음': 628,
#  '재미없는': 629,
#  '상미': 630,
#  '화이팅': 631,
#  '새끼': 632,
#  '충분히': 633,
#  '더럽게': 634,
#  '짓': 635,
#  '이에요': 636,
#  '해준': 637,
#  'ㅠㅠㅠ': 638,
#  '새로운': 639,
#  '술': 640,
#  '역': 641,
#  '불륜': 642,
#  '군': 643,
#  '귀': 644,
#  '알았는데': 645,
#  '병맛': 646,
#  '개그': 647,
#  '일이': 648,
#  '에겐': 649,
#  '엉망': 650,
#  '사건': 651,
#  '거지': 652,
#  '예상': 653,
#  '잠': 654,
#  '미화': 655,
#  '중반': 656,
#  '설명': 657,
#  '꿀잼': 658,
#  '그게': 659,
#  '어쩔': 660,
#  '과거': 661,
#  '있음': 662,
#  '프랑스': 663,
#  '화보': 664,
#  '키': 665,
#  '좋겠다': 666,
#  '따': 667,
#  '나옴': 668,
#  '흥미진진': 669,
#  '도저히': 670,
#  '손': 671,
#  '재밌는데': 672,
#  '노력': 673,
#  '댓글': 674,
#  '깊은': 675,
#  '그래픽': 676,
#  '여서': 677,
#  '죽음': 678,
#  '흥미': 679,
#  '거리': 680,
#  '같아': 681,
#  '척': 682,
#  '나올': 683,
#  '무조건': 684,
#  '취향': 685,
#  '였어요': 686,
#  '티': 687,
#  '원래': 688,
#  '몸': 689,
#  '나오고': 690,
#  '있게': 691,
#  '않음': 692,
#  '리': 693,
#  '화가': 694,
#  '한다는': 695,
#  '새': 696,
#  '따뜻한': 697,
#  '하는게': 698,
#  '알았다': 699,
#  '배': 700,
#  '현': 701,
#  '자극': 702,
#  '대단한': 703,
#  '감상': 704,
#  '암': 705,
#  '며': 706,
#  '만으로도': 707,
#  '예': 708,
#  '학교': 709,
#  '아까워': 710,
#  '괜히': 711,
#  '자꾸': 712,
#  '같습니다': 713,
#  '액션영화': 714,
#  '무': 715,
#  '관': 716,
#  '예고편': 717,
#  '오히려': 718,
#  '좋았어요': 719,
#  '바보': 720,
#  '결혼': 721,
#  '이라니': 722,
#  '다가': 723,
#  '아저씨': 724,
#  '엄청난': 725,
#  '아닌가': 726,
#  '심리': 727,
#  '게임': 728,
#  '이래': 729,
#  '속편': 730,
#  '재밌었다': 731,
#  '꺼': 732,
#  '용도': 733,
#  '기대하고': 734,
#  '흠': 735,
#  '미': 736,
#  '연기자': 737,
#  '안됨': 738,
#  '잘만': 739,
#  '마무리': 740,
#  '있을': 741,
#  '관계': 742,
#  '맨': 743,
#  '양': 744,
#  '천재': 745,
#  '법': 746,
#  '땐': 747,
#  '야할': 748,
#  'ㄷㄷ': 749,
#  '억지로': 750,
#  '표정': 751,
#  '귀신': 752,
#  '봤을': 753,
#  '전설': 754,
#  '영환': 755,
#  '순': 756,
#  '최근': 757,
#  '유치': 758,
#  '느끼게': 759,
#  '높은': 760,
#  '현재': 761,
#  '헐': 762,
#  '상상': 763,
#  '나쁜': 764,
#  '동': 765,
#  '드는': 766,
#  '타임': 767,
#  '지루': 768,
#  '젠': 769,
#  '촬영': 770,
#  '아쉬움': 771,
#  '봣': 772,
#  '오빠': 773,
#  '대한민국': 774,
#  '하는지': 775,
#  '오래': 776,
#  '완벽한': 777,
#  '산': 778,
#  '대작': 779,
#  '짐': 780,
#  '조차': 781,
#  '재미있고': 782,
#  '길': 783,
#  '우연히': 784,
#  '엇': 785,
#  '전편': 786,
#  '짜': 787,
#  '스타': 788,
#  '묘사': 789,
#  '재미없고': 790,
#  '메세지': 791,
#  '만의': 792,
#  '철학': 793,
#  '하는거': 794,
#  '일까': 795,
#  '타': 796,
#  '프로그램': 797,
#  '마': 798,
#  '동화': 799,
#  '살다': 800,
#  '프로': 801,
#  '그림': 802,
#  '만에': 803,
#  '있었다': 804,
#  '그렇고': 805,
#  '예요': 806,
#  '전달': 807,
#  '서로': 808,
#  '유머': 809,
#  '유치한': 810,
#  '공': 811,
#  '졸라': 812,
#  '역할': 813,
#  '지루하지': 814,
#  '무비': 815,
#  '등장': 816,
#  '쓴': 817,
#  '조연': 818,
#  '전작': 819,
#  '경찰': 820,
#  '스러운': 821,
#  '다행': 822,
#  '소녀': 823,
#  '이미': 824,
#  '먼저': 825,
#  '나중': 826,
#  '볼수': 827,
#  '했으면': 828,
#  '살인': 829,
#  '먹고': 830,
#  '마치': 831,
#  '모르는': 832,
#  '받아': 833,
#  '아쉬운': 834,
#  '특유': 835,
#  '힘든': 836,
#  '유치하고': 837,
#  '재미없어': 838,
#  '관심': 839,
#  '되었다': 840,
#  '비슷한': 841,
#  '이며': 842,
#  '보이는': 843,
#  '사이': 844,
#  '재밌었어요': 845,
#  '지난': 846,
#  '놔': 847,
#  '행동': 848,
#  '재밌어': 849,
#  '환상': 850,
#  '아닐까': 851,
#  '통해': 852,
#  '인정': 853,
#  '아니지만': 854,
#  '런가': 855,
#  '노출': 856,
#  '주의': 857,
#  '노': 858,
#  '왕': 859,
#  '맞는': 860,
#  '바람': 861,
#  '청춘': 862,
#  '지루해': 863,
#  '않았다': 864,
#  '미래': 865,
#  '낚': 866,
#  '입': 867,
#  '예산': 868,
#  '군대': 869,
#  '정': 870,
#  '리메이크': 871,
#  '안나': 872,
#  '하냐': 873,
#  '만들지': 874,
#  '깊이': 875,
#  '같아서': 876,
#  '안되고': 877,
#  '망작': 878,
#  '희망': 879,
#  'ㅇ': 880,
#  '보시길': 881,
#  '비추': 882,
#  '그닥': 883,
#  '좋았음': 884,
#  '제작비': 885,
#  '감사합니다': 886,
#  '께': 887,
#  'ㅅㅂ': 888,
#  '느낄': 889,
#  '효과': 890,
#  '재미있음': 891,
#  '생애': 892,
#  '영웅': 893,
#  '좋았습니다': 894,
#  '봤으면': 895,
#  '왠지': 896,
#  '으': 897,
#  '화려한': 898,
#  '해요': 899,
#  '손발': 900,
#  '진부한': 901,
#  '외': 902,
#  '보고나서': 903,
#  '엿': 904,
#  '돼': 905,
#  '시도': 906,
#  '필요없다': 907,
#  '과정': 908,
#  '보고싶다': 909,
#  '너무나도': 910,
#  '반개': 911,
#  '용이': 912,
#  '케이블': 913,
#  '평생': 914,
#  '긴': 915,
#  '아닌데': 916,
#  '나왔으면': 917,
#  '좋았고': 918,
#  '범인': 919,
#  '형님': 920,
#  '채널': 921,
#  '봤었는데': 922,
#  '있나': 923,
#  'ㅇㅇ': 924,
#  '미소': 925,
#  '이런거': 926,
#  '잘못': 927,
#  '이상한': 928,
#  '능력': 929,
#  '얼': 930,
#  '싫다': 931,
#  '생': 932,
#  '가끔': 933,
#  '만들었다': 934,
#  '강': 935,
#  '였는데': 936,
#  '상상력': 937,
#  '버렸다': 938,
#  '좋았는데': 939,
#  '약': 940,
#  '빼고': 941,
#  '스케일': 942,
#  '대단하다': 943,
#  '카메라': 944,
#  '기세': 945,
#  '이런게': 946,
#  '존': 947,
#  '결론': 948,
#  '그리': 949,
#  '없을': 950,
#  '광고': 951,
#  '나와': 952,
#  '않게': 953,
#  '독립영화': 954,
#  '그래': 955,
#  '저렇게': 956,
#  '의리': 957,
#  '체': 958,
#  '대충': 959,
#  '계': 960,
#  '확실히': 961,
#  '자막': 962,
#  '메시지': 963,
#  '낮은': 964,
#  '언니': 965,
#  '대안': 966,
#  '한계': 967,
#  '있다면': 968,
#  '줌': 969,
#  '드립니다': 970,
#  '부족': 971,
#  '고민': 972,
#  '부족한': 973,
#  '고생': 974,
#  '어이없는': 975,
#  '짱짱': 976,
#  '슬픔': 977,
#  '여성': 978,
#  '되게': 979,
#  '나를': 980,
#  '없나': 981,
#  '들어': 982,
#  '으로는': 983,
#  '메디': 984,
#  '봤다가': 985,
#  '보고싶은': 986,
#  '무서운': 987,
#  '않아': 988,
#  '있다는': 989,
#  '리얼': 990,
#  '없지만': 991,
#  '볼수록': 992,
#  '커플': 993,
#  '유쾌한': 994,
#  '든다': 995,
#  '차': 996,
#  '귀여운': 997,
#  '슬프다': 998,
#  '박수': 999,
#  '동생': 1000,
#  '이면': 1001,
#  ...}

# %%
id_to_word = {id:word for word,id in word_to_id.items()}
id_to_word
# Out:
# {2: '연기',
#  3: '평점',
#  4: '최고',
#  5: '스토리',
#  6: '드라마',
#  7: '감동',
#  8: 'ㅋㅋ',
#  9: '배우',
#  10: '감독',
#  11: '그냥',
#  12: '재미',
#  13: '내용',
#  14: '뭐',
#  15: '쓰레기',
#  16: '보다',
#  17: '없는',
#  18: '봤는데',
#  19: '작품',
#  20: '사랑',
#  21: '볼',
#  22: '마지막',
#  23: '좋은',
#  24: '이건',
#  25: '같은',
#  26: '완전',
#  27: 'ㅋ',
#  28: 'ㅠㅠ',
#  29: 'ㅋㅋㅋ',
#  30: '처음',
#  31: '장면',
#  32: '액션',
#  33: '주인공',
#  34: '보는',
#  35: '최악',
#  36: '돈',
#  37: '이야기',
#  38: '별로',
#  39: '봐도',
#  40: '느낌',
#  41: '참',
#  42: 'ㅡㅡ',
#  43: '연출',
#  44: '없고',
#  45: '명작',
#  46: '끝',
#  47: '역시',
#  48: '별',
#  49: '많이',
#  50: '재밌게',
#  51: '이해',
#  52: '이영화',
#  53: '분',
#  54: '성',
#  55: '아깝다',
#  56: '꼭',
#  57: '보기',
#  58: '짱',
#  59: '기억',
#  60: '결말',
#  61: 'ㅎㅎ',
#  62: '편',
#  63: '같다',
#  64: '마음',
#  65: '인생',
#  66: '영',
#  67: '소재',
#  68: '넘',
#  69: '님',
#  70: '수준',
#  71: '현실',
#  72: '한번',
#  73: '가장',
#  74: '급',
#  75: '매력',
#  76: '반전',
#  77: '전개',
#  78: '함',
#  79: '한국',
#  80: '남자',
#  81: '가슴',
#  82: '아이',
#  83: '음악',
#  84: '원작',
#  85: '만든',
#  86: '화',
#  87: '인간',
#  88: '추천',
#  89: '눈물',
#  90: '않고',
#  91: '인지',
#  92: '모든',
#  93: '봤다',
#  94: '자체',
#  95: '눈',
#  96: '인가',
#  97: '캐릭터',
#  98: '대박',
#  99: '코미디',
#  100: '처럼',
#  101: '솔직히',
#  102: 'ㅋㅋㅋㅋ',
#  103: '움',
#  104: '좋다',
#  105: '대한',
#  106: '모두',
#  107: '뭔가',
#  108: '이상',
#  109: 'ㅠ',
#  110: '했다',
#  111: '이네',
#  112: '전혀',
#  113: '연기력',
#  114: '여운',
#  115: '개봉',
#  116: '공감',
#  117: '기대',
#  118: '일본',
#  119: '시리즈',
#  120: '있다',
#  121: '허',
#  122: '근데',
#  123: '중간',
#  124: '표현',
#  125: '굿',
#  126: '아주',
#  127: '영상',
#  128: '부분',
#  129: '모습',
#  130: '에는',
#  131: '이라',
#  132: '작',
#  133: '계속',
#  134: '제목',
#  135: '이랑',
#  136: 'ㅜㅜ',
#  137: '재밌다',
#  138: '가족',
#  139: '내내',
#  140: '보지',
#  141: '뭔',
#  142: '봐',
#  143: '진심',
#  144: '재미있게',
#  145: '실망',
#  146: '없음',
#  147: '많은',
#  148: '하면',
#  149: '몰입',
#  150: '어떻게',
#  151: '후',
#  152: 'ㅎ',
#  153: '나오는',
#  154: '였다',
#  155: '기분',
#  156: '했는데',
#  157: '연',
#  158: '봤습니다',
#  159: '작가',
#  160: '건',
#  161: '건지',
#  162: '이제',
#  163: '않은',
#  164: '보면서',
#  165: '위',
#  166: '요즘',
#  167: '잼',
#  168: '공포',
#  169: '스릴러',
#  170: '아니고',
#  171: '이라는',
#  172: '감',
#  173: '시',
#  174: '용',
#  175: '긴장감',
#  176: '개인',
#  177: '점도',
#  178: '재미없다',
#  179: '않는',
#  180: '알바',
#  181: '애니',
#  182: '대사',
#  183: '아닌',
#  184: '이유',
#  185: '특히',
#  186: '제대로',
#  187: '삶',
#  188: '아까운',
#  189: '극장',
#  190: '노래',
#  191: '노잼',
#  192: '한테',
#  193: '점수',
#  194: '욕',
#  195: '시작',
#  196: '보다가',
#  197: '막장',
#  198: '아름다운',
#  199: '이란',
#  200: '나름',
#  201: '오랜',
#  202: '재밌어요',
#  203: '극',
#  204: '이지',
#  205: '에도',
#  206: '제일',
#  207: '차라리',
#  208: '놈',
#  209: '친구',
#  210: '좋고',
#  211: '영화로',
#  212: '보게',
#  213: '당시',
#  214: '봤어요',
#  215: '같이',
#  216: '의미',
#  217: '절대',
#  218: '식',
#  219: '보세요',
#  220: '만드는',
#  221: '위해',
#  222: '있고',
#  223: '력',
#  224: '류',
#  225: '세상',
#  226: '싶다',
#  227: '뻔한',
#  228: '아직도',
#  229: '년대',
#  230: '이라고',
#  231: '해도',
#  232: '공포영화',
#  233: '미국',
#  234: '웃음',
#  235: '도대체',
#  236: '아무',
#  237: '설정',
#  238: '보니',
#  239: '무엇',
#  240: '마다',
#  241: '너',
#  242: '초반',
#  243: '물',
#  244: '뭘',
#  245: '나도',
#  246: '수작',
#  247: '좋아하는',
#  248: '출연',
#  249: '우리나라',
#  250: '봄',
#  251: '추억',
#  252: '엄청',
#  253: '주고',
#  254: '좋았다',
#  255: '안되는',
#  256: '남는',
#  257: '한국영',
#  258: '보는내내',
#  259: '지루함',
#  260: '남',
#  261: '반',
#  262: '준다',
#  263: '시나리오',
#  264: '주는',
#  265: '관객',
#  266: '이야',
#  267: '분위기',
#  268: '장난',
#  269: '팬',
#  270: '든',
#  271: '좋아요',
#  272: '시대',
#  273: '된다',
#  274: '지루하고',
#  275: '졸작',
#  276: '세',
#  277: '이딴',
#  278: '봤던',
#  279: '감정',
#  280: '최고다',
#  281: '같아요',
#  282: '준',
#  283: '엔딩',
#  284: '접',
#  285: '영화관',
#  286: '오늘',
#  287: '엄마',
#  288: '구',
#  289: '결국',
#  290: '제발',
#  291: '정신',
#  292: '인상',
#  293: '라면',
#  294: '더빙',
#  295: '포스터',
#  296: '캐스팅',
#  297: '평가',
#  298: '코믹',
#  299: '니까',
#  300: '아무리',
#  301: '될',
#  302: '엉',
#  303: '멋진',
#  304: '애니메이션',
#  305: '그저',
#  306: '함께',
#  307: '음',
#  308: '몰입도',
#  309: '신',
#  310: '괜찮은',
#  311: '킬링타임',
#  312: '어릴',
#  313: '티비',
#  314: '했던',
#  315: '봐서',
#  316: '기도',
#  317: '재밌음',
#  318: '배경',
#  319: '첨',
#  320: '뒤',
#  321: '맘',
#  322: '충격',
#  323: '스릴',
#  324: '전쟁',
#  325: '만화',
#  326: '얘기',
#  327: '존나',
#  328: '책',
#  329: '개연',
#  330: '건가',
#  331: '같은데',
#  332: '예술',
#  333: '간',
#  334: '싶은',
#  335: '머리',
#  336: '매우',
#  337: '머',
#  338: '갈수록',
#  339: '질',
#  340: '조',
#  341: '보단',
#  342: '웃기',
#  343: '얼굴',
#  344: '큰',
#  345: '후회',
#  346: '이름',
#  347: '재밌는',
#  348: '옛날',
#  349: '영화인',
#  350: '너무나',
#  351: '구성',
#  352: '나온',
#  353: '하면서',
#  354: '집중',
#  355: '이후',
#  356: '울',
#  357: '까',
#  358: '총',
#  359: '않는다',
#  360: '꽤',
#  361: '장르',
#  362: '지루한',
#  363: '만들어',
#  364: '날',
#  365: '봐라',
#  366: '주연',
#  367: '하는데',
#  368: '다큐',
#  369: '시즌',
#  370: '상황',
#  371: '누구',
#  372: '지루하다',
#  373: '모르겠다',
#  374: '재미없음',
#  375: '상',
#  376: '이리',
#  377: '씬',
#  378: '짜증',
#  379: '억지',
#  380: '예전',
#  381: '강추',
#  382: '글',
#  383: '아직',
#  384: '비',
#  385: '후반',
#  386: '역사',
#  387: '다운',
#  388: '보는데',
#  389: '어느',
#  390: '먹',
#  391: '걸작',
#  392: '아님',
#  393: '진',
#  394: '마세요',
#  395: '누가',
#  396: '했지만',
#  397: '자기',
#  398: '소름',
#  399: '만점',
#  400: '인물',
#  401: '실화',
#  402: '발연기',
#  403: '본다',
#  404: '그나마',
#  405: '그대로',
#  406: '방송',
#  407: '분들',
#  408: '시절',
#  409: '봤음',
#  410: '아까',
#  411: '회',
#  412: '비디오',
#  413: '대체',
#  414: '할수',
#  415: '없어',
#  416: '한마디',
#  417: '소설',
#  418: '재밌고',
#  419: '부',
#  420: '로맨스',
#  421: '봤지만',
#  422: '초딩',
#  423: '아들',
#  424: '비교',
#  425: '됨',
#  426: '감성',
#  427: '판',
#  428: '네이버',
#  429: '다음',
#  430: '여주',
#  431: '여배우',
#  432: '전체',
#  433: '나와서',
#  434: '이었다',
#  435: '간만',
#  436: '해야',
#  437: '죠',
#  438: '꿈',
#  439: '좋은데',
#  440: '장',
#  441: '라도',
#  442: '없네',
#  443: '같음',
#  444: '나이',
#  445: '이라도',
#  446: '성룡',
#  447: '코',
#  448: '나라',
#  449: '재',
#  450: '였습니다',
#  451: '재밋',
#  452: '동안',
#  453: '혼자',
#  454: '어렸을',
#  455: '열',
#  456: '삼류',
#  457: '없어서',
#  458: '순간',
#  459: '교훈',
#  460: '쯤',
#  461: '보다는',
#  462: '아쉽다',
#  463: '재미있어요',
#  464: 'ㅉㅉ',
#  465: '없었다',
#  466: '빨리',
#  467: '그만',
#  468: '가는',
#  469: '존재',
#  470: '힘',
#  471: '바로',
#  472: '미친',
#  473: '하네요',
#  474: '주제',
#  475: '어설픈',
#  476: '낸',
#  477: '목소리',
#  478: '낭비',
#  479: '에요',
#  480: '년도',
#  481: '억',
#  482: '진정한',
#  483: '죽',
#  484: '짜리',
#  485: '당신',
#  486: '는데',
#  487: '안보',
#  488: '몇번',
#  489: '질질',
#  490: '년전',
#  491: '굳',
#  492: '라니',
#  493: '잔잔한',
#  494: '말고',
#  495: '줄거리',
#  496: '상당히',
#  497: '재미있다',
#  498: '판타지',
#  499: 'ㅜ',
#  500: '의도',
#  501: '에선',
#  502: '딸',
#  503: '이번',
#  504: '갑자기',
#  505: '아버지',
#  506: '좀비',
#  507: '좋아',
#  508: '있지만',
#  509: '보여주는',
#  510: '어른',
#  511: '되고',
#  512: '전부',
#  513: '피',
#  514: '재밌네요',
#  515: '점주',
#  516: '당',
#  517: '상영',
#  518: '모',
#  519: '시청률',
#  520: 'ㅎㅎㅎ',
#  521: '실제',
#  522: '소',
#  523: '믿고',
#  524: '있을까',
#  525: '만하',
#  526: 'ㅡ',
#  527: '하며',
#  528: '으로도',
#  529: '봤네요',
#  530: '평론가',
#  531: '곳',
#  532: '맛',
#  533: '점점',
#  534: '필요',
#  535: '땜',
#  536: '비해',
#  537: '단',
#  538: '재미있는',
#  539: '난다',
#  540: '버린',
#  541: '쳐',
#  542: '막',
#  543: '한편',
#  544: '히',
#  545: '제작',
#  546: '화면',
#  547: '사',
#  548: '바',
#  549: '같네요',
#  550: '대로',
#  551: '극장판',
#  552: '초',
#  553: '평',
#  554: '간다',
#  555: '답',
#  556: '중국',
#  557: '형',
#  558: '하네',
#  559: '있는데',
#  560: '있어',
#  561: '온',
#  562: '되지',
#  563: '각본',
#  564: '에서도',
#  565: '래',
#  566: '밑',
#  567: '나온다',
#  568: '볼때',
#  569: '굉장히',
#  570: '이하',
#  571: '훌륭한',
#  572: '있어서',
#  573: '관람',
#  574: '란',
#  575: '저런',
#  576: '선',
#  577: '스타일',
#  578: '올',
#  579: '일단',
#  580: '세계',
#  581: '가치',
#  582: '참고',
#  583: '선택',
#  584: '좋네요',
#  585: '성우',
#  586: '똥',
#  587: '요소',
#  588: '항상',
#  589: '터',
#  590: '둘',
#  591: '그런지',
#  592: '복수',
#  593: '봐야',
#  594: '어디서',
#  595: '햇',
#  596: '에서는',
#  597: '뻔',
#  598: '첫',
#  599: '흥행',
#  600: '해주는',
#  601: '어린',
#  602: '모르고',
#  603: '그때',
#  604: '드',
#  605: '여러',
#  606: '더욱',
#  607: '치고',
#  608: '없네요',
#  609: '진행',
#  610: '였음',
#  611: '슬픈',
#  612: '라서',
#  613: '이냐',
#  614: '좋음',
#  615: '인거',
#  616: '거기',
#  617: '아빠',
#  618: '씩',
#  619: '수가',
#  620: '역대',
#  621: '발',
#  622: '보는게',
#  623: 'ㅋㅋㅋㅋㅋ',
#  624: '완성',
#  625: '전형',
#  626: '편집',
#  627: '멜로',
#  628: '했음',
#  629: '재미없는',
#  630: '상미',
#  631: '화이팅',
#  632: '새끼',
#  633: '충분히',
#  634: '더럽게',
#  635: '짓',
#  636: '이에요',
#  637: '해준',
#  638: 'ㅠㅠㅠ',
#  639: '새로운',
#  640: '술',
#  641: '역',
#  642: '불륜',
#  643: '군',
#  644: '귀',
#  645: '알았는데',
#  646: '병맛',
#  647: '개그',
#  648: '일이',
#  649: '에겐',
#  650: '엉망',
#  651: '사건',
#  652: '거지',
#  653: '예상',
#  654: '잠',
#  655: '미화',
#  656: '중반',
#  657: '설명',
#  658: '꿀잼',
#  659: '그게',
#  660: '어쩔',
#  661: '과거',
#  662: '있음',
#  663: '프랑스',
#  664: '화보',
#  665: '키',
#  666: '좋겠다',
#  667: '따',
#  668: '나옴',
#  669: '흥미진진',
#  670: '도저히',
#  671: '손',
#  672: '재밌는데',
#  673: '노력',
#  674: '댓글',
#  675: '깊은',
#  676: '그래픽',
#  677: '여서',
#  678: '죽음',
#  679: '흥미',
#  680: '거리',
#  681: '같아',
#  682: '척',
#  683: '나올',
#  684: '무조건',
#  685: '취향',
#  686: '였어요',
#  687: '티',
#  688: '원래',
#  689: '몸',
#  690: '나오고',
#  691: '있게',
#  692: '않음',
#  693: '리',
#  694: '화가',
#  695: '한다는',
#  696: '새',
#  697: '따뜻한',
#  698: '하는게',
#  699: '알았다',
#  700: '배',
#  701: '현',
#  702: '자극',
#  703: '대단한',
#  704: '감상',
#  705: '암',
#  706: '며',
#  707: '만으로도',
#  708: '예',
#  709: '학교',
#  710: '아까워',
#  711: '괜히',
#  712: '자꾸',
#  713: '같습니다',
#  714: '액션영화',
#  715: '무',
#  716: '관',
#  717: '예고편',
#  718: '오히려',
#  719: '좋았어요',
#  720: '바보',
#  721: '결혼',
#  722: '이라니',
#  723: '다가',
#  724: '아저씨',
#  725: '엄청난',
#  726: '아닌가',
#  727: '심리',
#  728: '게임',
#  729: '이래',
#  730: '속편',
#  731: '재밌었다',
#  732: '꺼',
#  733: '용도',
#  734: '기대하고',
#  735: '흠',
#  736: '미',
#  737: '연기자',
#  738: '안됨',
#  739: '잘만',
#  740: '마무리',
#  741: '있을',
#  742: '관계',
#  743: '맨',
#  744: '양',
#  745: '천재',
#  746: '법',
#  747: '땐',
#  748: '야할',
#  749: 'ㄷㄷ',
#  750: '억지로',
#  751: '표정',
#  752: '귀신',
#  753: '봤을',
#  754: '전설',
#  755: '영환',
#  756: '순',
#  757: '최근',
#  758: '유치',
#  759: '느끼게',
#  760: '높은',
#  761: '현재',
#  762: '헐',
#  763: '상상',
#  764: '나쁜',
#  765: '동',
#  766: '드는',
#  767: '타임',
#  768: '지루',
#  769: '젠',
#  770: '촬영',
#  771: '아쉬움',
#  772: '봣',
#  773: '오빠',
#  774: '대한민국',
#  775: '하는지',
#  776: '오래',
#  777: '완벽한',
#  778: '산',
#  779: '대작',
#  780: '짐',
#  781: '조차',
#  782: '재미있고',
#  783: '길',
#  784: '우연히',
#  785: '엇',
#  786: '전편',
#  787: '짜',
#  788: '스타',
#  789: '묘사',
#  790: '재미없고',
#  791: '메세지',
#  792: '만의',
#  793: '철학',
#  794: '하는거',
#  795: '일까',
#  796: '타',
#  797: '프로그램',
#  798: '마',
#  799: '동화',
#  800: '살다',
#  801: '프로',
#  802: '그림',
#  803: '만에',
#  804: '있었다',
#  805: '그렇고',
#  806: '예요',
#  807: '전달',
#  808: '서로',
#  809: '유머',
#  810: '유치한',
#  811: '공',
#  812: '졸라',
#  813: '역할',
#  814: '지루하지',
#  815: '무비',
#  816: '등장',
#  817: '쓴',
#  818: '조연',
#  819: '전작',
#  820: '경찰',
#  821: '스러운',
#  822: '다행',
#  823: '소녀',
#  824: '이미',
#  825: '먼저',
#  826: '나중',
#  827: '볼수',
#  828: '했으면',
#  829: '살인',
#  830: '먹고',
#  831: '마치',
#  832: '모르는',
#  833: '받아',
#  834: '아쉬운',
#  835: '특유',
#  836: '힘든',
#  837: '유치하고',
#  838: '재미없어',
#  839: '관심',
#  840: '되었다',
#  841: '비슷한',
#  842: '이며',
#  843: '보이는',
#  844: '사이',
#  845: '재밌었어요',
#  846: '지난',
#  847: '놔',
#  848: '행동',
#  849: '재밌어',
#  850: '환상',
#  851: '아닐까',
#  852: '통해',
#  853: '인정',
#  854: '아니지만',
#  855: '런가',
#  856: '노출',
#  857: '주의',
#  858: '노',
#  859: '왕',
#  860: '맞는',
#  861: '바람',
#  862: '청춘',
#  863: '지루해',
#  864: '않았다',
#  865: '미래',
#  866: '낚',
#  867: '입',
#  868: '예산',
#  869: '군대',
#  870: '정',
#  871: '리메이크',
#  872: '안나',
#  873: '하냐',
#  874: '만들지',
#  875: '깊이',
#  876: '같아서',
#  877: '안되고',
#  878: '망작',
#  879: '희망',
#  880: 'ㅇ',
#  881: '보시길',
#  882: '비추',
#  883: '그닥',
#  884: '좋았음',
#  885: '제작비',
#  886: '감사합니다',
#  887: '께',
#  888: 'ㅅㅂ',
#  889: '느낄',
#  890: '효과',
#  891: '재미있음',
#  892: '생애',
#  893: '영웅',
#  894: '좋았습니다',
#  895: '봤으면',
#  896: '왠지',
#  897: '으',
#  898: '화려한',
#  899: '해요',
#  900: '손발',
#  901: '진부한',
#  902: '외',
#  903: '보고나서',
#  904: '엿',
#  905: '돼',
#  906: '시도',
#  907: '필요없다',
#  908: '과정',
#  909: '보고싶다',
#  910: '너무나도',
#  911: '반개',
#  912: '용이',
#  913: '케이블',
#  914: '평생',
#  915: '긴',
#  916: '아닌데',
#  917: '나왔으면',
#  918: '좋았고',
#  919: '범인',
#  920: '형님',
#  921: '채널',
#  922: '봤었는데',
#  923: '있나',
#  924: 'ㅇㅇ',
#  925: '미소',
#  926: '이런거',
#  927: '잘못',
#  928: '이상한',
#  929: '능력',
#  930: '얼',
#  931: '싫다',
#  932: '생',
#  933: '가끔',
#  934: '만들었다',
#  935: '강',
#  936: '였는데',
#  937: '상상력',
#  938: '버렸다',
#  939: '좋았는데',
#  940: '약',
#  941: '빼고',
#  942: '스케일',
#  943: '대단하다',
#  944: '카메라',
#  945: '기세',
#  946: '이런게',
#  947: '존',
#  948: '결론',
#  949: '그리',
#  950: '없을',
#  951: '광고',
#  952: '나와',
#  953: '않게',
#  954: '독립영화',
#  955: '그래',
#  956: '저렇게',
#  957: '의리',
#  958: '체',
#  959: '대충',
#  960: '계',
#  961: '확실히',
#  962: '자막',
#  963: '메시지',
#  964: '낮은',
#  965: '언니',
#  966: '대안',
#  967: '한계',
#  968: '있다면',
#  969: '줌',
#  970: '드립니다',
#  971: '부족',
#  972: '고민',
#  973: '부족한',
#  974: '고생',
#  975: '어이없는',
#  976: '짱짱',
#  977: '슬픔',
#  978: '여성',
#  979: '되게',
#  980: '나를',
#  981: '없나',
#  982: '들어',
#  983: '으로는',
#  984: '메디',
#  985: '봤다가',
#  986: '보고싶은',
#  987: '무서운',
#  988: '않아',
#  989: '있다는',
#  990: '리얼',
#  991: '없지만',
#  992: '볼수록',
#  993: '커플',
#  994: '유쾌한',
#  995: '든다',
#  996: '차',
#  997: '귀여운',
#  998: '슬프다',
#  999: '박수',
#  1000: '동생',
#  1001: '이면',
#  ...}

# %%
encoded
# Out:
# [[294, 0, 477],
#  [735, 295, 422, 1353, 2, 781, 0, 0],
#  [241, 2625, 0, 2455, 0, 0, 88],
#  [0, 37, 0, 101, 12, 3, 4144],
#  [844, 0, 0, 2, 0, 2784, 0, 0, 314, 0, 0, 910, 3416, 4326],
#  [542, 0, 798, 0, 276, 1659, 1576, 0, 0, 29, 48, 911, 410, 103],
#  [84, 175, 186, 0, 110],
#  [48,
#   911,
#   55,
#   194,
#   567,
#   0,
#   0,
#   157,
#   1520,
#   91,
#   621,
#   231,
#   341,
#   0,
#   3479,
#   0,
#   1285,
#   1285,
#   6,
#   138,
#   2,
#   518,
#   904],
#  [32, 0, 12, 255],
#  [1455, 3, 0, 360, 21, 1342, 218, 0, 0, 923],
#  [0, 58, 58],
#  [568, 240, 0, 0, 229, 2717, 203, 0, 426, 2676, 627, 0],
#  [2372, 671, 0, 0, 4145, 0, 578, 597, 4233, 2, 1277],
#  [0, 0, 104, 309, 1051, 547, 1380, 16, 712, 0, 0],
#  [685, 4529, 0, 1785, 189, 73, 191, 858, 7, 5, 2423, 7, 2423],
#  [1670, 1074, 2755, 1267, 511, 2070, 28],
#  [41,
#   0,
#   0,
#   1140,
#   0,
#   447,
#   0,
#   0,
#   1140,
#   1295,
#   230,
#   0,
#   2455,
#   1074,
#   0,
#   0,
#   100,
#   1226],
#  [0, 0, 1034, 51, 367, 320, 338, 12, 0],
#  [24, 2650, 296, 0, 163, 0, 0, 0, 2650, 4428],
#  [0, 165, 0, 131, 208, 1644, 208, 217, 183],
#  [200, 3824, 1101, 11, 1435, 2785, 0, 217, 392],
#  [164, 0, 179, 160, 0],
#  [178,
#   274,
#   25,
#   2276,
#   0,
#   0,
#   68,
#   1191,
#   0,
#   0,
#   0,
#   37,
#   222,
#   2276,
#   34,
#   12,
#   559,
#   24,
#   21,
#   2276,
#   38,
#   690,
#   0,
#   1591,
#   445,
#   288,
#   1446,
#   0,
#   486,
#   38,
#   668,
#   42],
#  [217, 1081, 183, 246, 131, 1085, 0],
#  [474, 439, 656, 372],
#  [0, 3183, 0, 0, 56, 0, 0],
#  [0, 0, 0, 0],
#  [0, 3417, 402],
#  [0],
#  [2306, 43, 223, 3909, 296, 229, 2717],
#  [0, 0, 72, 1819, 637, 0, 2049, 3184, 69, 2, 719, 26, 1413, 6],
#  [2349, 15, 0, 1456, 0, 8, 3988, 333, 710],
#  [672, 48, 376, 0],
#  [441, 4832, 0, 0],
#  [228, 6, 65, 4],
#  [4327, 105, 1209, 872, 0, 0],
#  [0, 0, 2, 1507, 0, 413, 0, 795, 0, 795],
#  [159, 291, 2786, 3480, 131, 0],
#  [295, 560, 4328, 265, 111],
#  [297, 0, 373],
#  [0, 0, 75],
#  [3231, 96, 13, 44, 0, 44, 0, 146, 26, 48, 0, 924, 880, 68, 410, 103, 26, 0],
#  [0, 0, 0, 0],
#  [321, 0, 2787, 34, 1362, 442, 0],
#  [0,
#   171,
#   303,
#   9,
#   1052,
#   4728,
#   1948,
#   1973,
#   493,
#   925,
#   0,
#   83,
#   1457,
#   28,
#   253,
#   1621,
#   3,
#   0,
#   2424,
#   0],
#  [3, 2718, 1899, 478, 36, 478],
#  [2527,
#   0,
#   1521,
#   344,
#   116,
#   554,
#   3825,
#   97,
#   0,
#   375,
#   0,
#   3185,
#   3989,
#   0,
#   0,
#   0,
#   1871,
#   194,
#   4329,
#   0,
#   548,
#   610,
#   203,
#   242,
#   0,
#   1227,
#   338,
#   3825,
#   291,
#   1820,
#   116,
#   1167],
#  [1562, 2090, 27, 0, 70, 0, 464, 1150, 926, 0, 36, 0],
#  [20],
#  [241,
#   4729,
#   0,
#   0,
#   0,
#   0,
#   3677,
#   511,
#   226,
#   3678,
#   135,
#   0,
#   0,
#   417,
#   501,
#   206,
#   303,
#   208,
#   2091,
#   0,
#   589,
#   936,
#   6,
#   501,
#   0,
#   912,
#   206,
#   0,
#   234,
#   10,
#   69,
#   0,
#   4234,
#   4066,
#   0,
#   1218,
#   0,
#   628],
#  [1563, 0, 1056, 0, 0, 276, 0, 2133, 2788, 799, 25, 0],
#  [0, 1422, 0, 0, 532, 0, 0, 0, 2816, 0, 554],
#  [81, 0, 6, 524, 7, 94],
#  [0, 1853, 1974, 0, 0, 2277, 11, 453, 0, 4235],
#  [463],
#  [271],
#  [4],
#  [322,
#   0,
#   155,
#   1622,
#   1401,
#   0,
#   40,
#   4634,
#   223,
#   0,
#   17,
#   910,
#   2848,
#   0,
#   0,
#   0,
#   305,
#   2278,
#   937,
#   0,
#   3418,
#   995],
#  [4530],
#  [0, 0],
#  [258, 405, 0, 2849, 1564, 17, 1057],
#  [0, 433, 2071, 2323, 123, 1660, 40],
#  [0, 0, 1081, 1075, 0, 735],
#  [0,
#   133,
#   2585,
#   1402,
#   4833,
#   33,
#   0,
#   4834,
#   2554,
#   0,
#   522,
#   2935,
#   129,
#   378,
#   136,
#   1318,
#   0,
#   4730,
#   1192,
#   77,
#   466,
#   466,
#   136],
#  [20, 0, 4731, 561, 279, 0, 806, 4],
#  [147,
#   368,
#   249,
#   611,
#   2176,
#   0,
#   0,
#   875,
#   0,
#   471,
#   0,
#   221,
#   673,
#   828,
#   1132,
#   0,
#   0,
#   0,
#   0,
#   3679,
#   1478,
#   266,
#   24,
#   0,
#   829,
#   3363,
#   3607],
#  [380,
#   19,
#   97,
#   1458,
#   4531,
#   1186,
#   0,
#   0,
#   1821,
#   0,
#   13,
#   778,
#   1447,
#   519,
#   1786,
#   690,
#   162,
#   411,
#   656,
#   2307,
#   722],
#  [0, 1302, 484, 113, 242, 308, 205, 1239, 274, 3419, 0],
#  [1289, 841, 1975, 53, 192, 4835],
#  [0, 0, 0, 0, 0, 0],
#  [118, 330, 1645],
#  [0,
#   803,
#   214,
#   202,
#   122,
#   996,
#   4329,
#   4836,
#   1787,
#   1680,
#   148,
#   996,
#   0,
#   0,
#   0,
#   0,
#   0,
#   3125,
#   0,
#   0,
#   1787,
#   0,
#   0,
#   0,
#   29,
#   160,
#   0,
#   13,
#   94,
#   719],
#  [275],
#  [3910, 0, 1053, 612, 845],
#  [475, 77, 975, 60],
#  [0, 0, 0, 4732, 0, 4532, 0, 314, 2528, 0, 305, 0],
#  [13, 77, 2626, 0, 1531],
#  [336, 145],
#  [257, 86, 599, 1122, 1388, 1388, 960, 1388, 4733, 7, 3, 4146, 599, 0, 14],
#  [0, 0, 0],
#  [14, 195, 1913, 2248, 0, 1744, 1553, 0],
#  [1459, 4, 0],
#  [10, 0, 830, 0, 265, 244, 0, 1436, 650, 3420, 3420],
#  [24, 14, 2279],
#  [15],
#  [1054, 1539, 4],
#  [1311, 154],
#  [2425, 117],
#  [122, 0, 0, 0, 1428],
#  [29, 0, 8, 95, 0, 0, 8],
#  [446, 35, 8],
#  [2035, 0, 102, 0, 0, 0],
#  [4734, 2177],
#  [26, 202, 623, 1302, 0, 0, 103, 1354],
#  [292, 154],
#  [0, 0, 26, 381, 479, 1086],
#  [538],
#  [3232, 3186, 0, 1577, 916],
#  [164, 0],
#  [237, 418, 639, 1458, 4067, 5, 0, 4964, 317],
#  [0, 0, 3074, 736, 1016, 0, 2, 3026, 98, 154],
#  [374, 143, 0, 296],
#  [0, 16, 21, 615, 713, 27],
#  [10, 69, 0, 4735, 1058],
#  [1278, 3990, 5, 42],
#  [3126, 3991, 640, 951, 0, 2306, 691, 828, 0],
#  [311],
#  [1681, 148, 4429],
#  [144, 158, 75, 1210, 111, 520],
#  [83, 1622, 2478, 21, 1043, 1228, 0, 2308],
#  [1976, 30, 16, 123, 0, 642, 420],
#  [859, 378, 126, 77, 2789, 0, 0, 3541, 3277, 0],
#  [101, 0, 478, 40],
#  [98],
#  [519, 1623, 0, 0, 337, 0, 45, 6, 3127, 42, 0],
#  [13, 3075],
#  [0, 0, 50, 93],
#  [13, 77, 350, 0],
#  [67, 679, 1158, 37, 77, 1682, 0, 149, 0],
#  [217, 1355, 15],
#  [4330,
#   835,
#   1389,
#   0,
#   560,
#   0,
#   0,
#   817,
#   673,
#   0,
#   2988,
#   701,
#   1211,
#   1087,
#   237,
#   0,
#   1067,
#   235,
#   1390,
#   2756,
#   1035,
#   91],
#  [11, 0, 2426, 3027, 2555, 0, 0, 233, 697, 237, 24, 2108],
#  [0, 33, 892, 512, 0],
#  [48, 533, 3911],
#  [38],
#  [2178, 360, 846, 151, 0, 2529],
#  [795],
#  [2677, 212, 39, 1008, 20, 7, 28, 0, 2],
#  [2850,
#   1683,
#   0,
#   409,
#   8,
#   762,
#   5,
#   737,
#   112,
#   1730,
#   135,
#   2851,
#   692,
#   2817,
#   9,
#   1684,
#   0,
#   443,
#   24,
#   737,
#   662,
#   1151,
#   143,
#   26,
#   38,
#   0,
#   423,
#   1102,
#   21,
#   628],
#  [2015, 0, 389, 1565, 0, 186, 0],
#  [1766],
#  [0, 126, 0],
#  [126, 0],
#  [2790, 0, 25, 448, 0, 0],
#  [4532, 0, 1854, 0],
#  [782, 459, 66, 0],
#  [213, 370, 474, 0, 3076, 183, 175, 222, 50, 2556, 19],
#  [913, 467, 952, 0],
#  [0, 0, 613, 0, 0, 0, 1822, 2789, 0, 0],
#  [0, 167, 146, 14, 161, 42, 167, 146, 0, 167, 146, 0, 162],
#  [0],
#  [3077, 3078, 2, 0, 0, 1256, 49, 475],
#  [101,
#   0,
#   0,
#   0,
#   3233,
#   212,
#   19,
#   54,
#   564,
#   490,
#   57,
#   0,
#   2678,
#   0,
#   403,
#   22,
#   385,
#   4430,
#   1029,
#   3826,
#   246,
#   230,
#   403,
#   1173,
#   163],
#  [21, 1554],
#  [4736, 0, 0, 394],
#  [4635, 3128, 27],
#  [162,
#   1290,
#   2373,
#   1605,
#   65,
#   4,
#   1661,
#   3827,
#   0,
#   19,
#   150,
#   0,
#   980,
#   165,
#   972,
#   72,
#   0,
#   3912,
#   0,
#   444,
#   3913,
#   1059,
#   0],
#  [159, 38, 912, 38, 1318, 11, 117, 3680, 148, 3481, 0, 0, 555],
#  [45, 45, 524, 226, 39, 114, 256],
#  [671,
#   2679,
#   1540,
#   953,
#   1103,
#   0,
#   363,
#   339,
#   1798,
#   1457,
#   633,
#   2651,
#   176,
#   4636,
#   702,
#   0,
#   0,
#   0,
#   0,
#   3028,
#   49,
#   0,
#   2456],
#  [467, 1158, 162, 2530, 2350, 4837],
#  [],
#  [47, 2719, 2, 1662, 245, 4068, 2586, 0, 0],
#  [200, 310, 19],
#  [23],
#  [145, 0],
#  [9, 3914, 0, 0, 0, 0, 0, 0, 3914, 0],
#  [1009, 0, 312, 2479, 3760, 4838, 0],
#  [1701, 0],
#  [],
#  [0, 0, 2680, 1460, 199, 28],
#  [79, 501, 4839, 543, 854, 1326, 501, 763, 2897, 1624],
#  [201, 451, 529],
#  [0,
#   2791,
#   286,
#   542,
#   0,
#   214,
#   406,
#   1932,
#   360,
#   624,
#   989,
#   40,
#   0,
#   166,
#   6,
#   197,
#   0,
#   0,
#   0,
#   6,
#   0,
#   1057,
#   949,
#   1855,
#   0,
#   0,
#   631],
#  [3,
#   1423,
#   3992,
#   0,
#   234,
#   0,
#   2425,
#   0,
#   1994,
#   0,
#   756,
#   2150,
#   813,
#   206,
#   0,
#   0,
#   2818,
#   3278,
#   2,
#   166,
#   1076,
#   0,
#   105,
#   157,
#   0,
#   896,
#   99,
#   31,
#   443,
#   234],
#  [46, 4637, 460, 0, 1374, 416, 0, 2351, 63],
#  [2792, 0, 520],
#  [0, 0, 0, 54, 199, 67, 2531, 0, 110],
#  [0, 483, 607, 0, 0, 21, 184, 17, 19],
#  [0],
#  [0,
#   0,
#   1009,
#   2557,
#   2179,
#   2016,
#   179,
#   160,
#   2627,
#   728,
#   0,
#   90,
#   0,
#   171,
#   33,
#   0,
#   38,
#   178,
#   318,
#   0],
#  [1133,
#   2249,
#   0,
#   650,
#   0,
#   1193,
#   0,
#   13,
#   0,
#   597,
#   33,
#   477,
#   4840,
#   1141,
#   0,
#   0,
#   0,
#   143,
#   0,
#   3187,
#   1731,
#   868,
#   174,
#   0,
#   1914,
#   0,
#   738],
#  [0, 0, 360, 3542, 3029],
#  [0, 602, 1788],
#  [180, 732],
#  [337, 0, 833, 1833, 0, 9, 3030, 10, 0, 610],
#  [0, 35],
#  [198],
#  [702, 0, 0, 39, 95, 0, 836, 43, 223],
#  [0, 1933, 3828, 245, 0],
#  [378,
#   1448,
#   509,
#   569,
#   0,
#   40,
#   0,
#   2532,
#   80,
#   402,
#   3031,
#   0,
#   0,
#   3829,
#   0,
#   493,
#   2936,
#   1915,
#   83,
#   3761,
#   2652,
#   2989,
#   0,
#   496,
#   2937],
#  [7, 7, 136, 4],
#  [48,
#   1356,
#   2374,
#   13,
#   0,
#   194,
#   2533,
#   1789,
#   422,
#   1429,
#   0,
#   694,
#   1152,
#   236,
#   21,
#   1702,
#   140,
#   394,
#   11,
#   313,
#   427,
#   3032,
#   549],
#  [0, 378, 0],
#  [2204, 513, 830, 0, 0, 31, 501, 0, 47, 0, 3125, 698],
#  [2180],
#  [837, 274, 654, 2280],
#  [224, 1915, 498, 0],
#  [0,
#   0,
#   1625,
#   0,
#   235,
#   0,
#   4737,
#   0,
#   1268,
#   0,
#   3129,
#   4431,
#   0,
#   1268,
#   0,
#   0,
#   0,
#   467,
#   0],
#  [0, 19, 348, 226],
#  [932, 4],
#  [1745, 1934, 144, 278, 251, 0, 217, 764, 0, 0, 2819, 1428],
#  [2398, 2938, 3130, 0, 1680, 0, 279, 2676, 0, 0],
#  [0, 0, 0, 1492, 4432, 552, 803, 0, 8, 217, 0, 90, 345, 1456, 0],
#  [52, 299, 459, 3421, 245, 2109, 65, 0, 0, 2533],
#  [200, 251, 0, 1790, 884, 8, 236, 1249, 0, 88],
#  [1437, 1592, 243, 0],
#  [480, 0, 1428, 380, 3234, 115, 330, 109, 121, 0, 109],
#  [68, 1357, 28, 157, 93, 68, 1949, 28],
#  [862, 426, 0, 539, 458, 0, 0, 0, 458, 1593, 2558, 4147, 426],
#  [174, 0, 119, 383, 1269, 2399],
#  [2628, 166, 338, 0, 191, 234, 2852],
#  [4841, 0, 0, 0, 136, 7],
#  [0,
#   20,
#   1732,
#   2629,
#   124,
#   562,
#   0,
#   173,
#   0,
#   2939,
#   0,
#   184,
#   173,
#   858,
#   3608,
#   2281,
#   897,
#   0,
#   1363,
#   173,
#   858,
#   2720,
#   2676,
#   544,
#   1578,
#   173,
#   1680,
#   673,
#   0,
#   0,
#   2681,
#   2682],
#  [1343, 118, 512, 275, 118, 565, 729],
#  [0, 0, 0, 0, 309],
#  [0, 0, 0, 3482],
#  [0, 1334, 226],
#  [898, 4533, 0, 0, 8, 1685, 8, 0, 157, 899, 27],
#  [0, 165, 2534, 2630],
#  [7],
#  [24, 534, 11, 3131, 365],
#  [0, 418, 303, 20],
#  [47, 0, 3483, 1703, 17, 0, 0, 938, 4],
#  [0],
#  [0, 2631, 0, 1390, 194, 0, 102],
#  [342, 2653, 0, 0, 0, 559],
#  [351, 496, 0, 47, 428, 3, 0],
#  [0, 3422, 4638, 0, 4069, 1342, 19, 73, 0, 275],
#  [1030, 0, 3364, 43, 91, 71, 54, 1229],
#  [0, 205, 0, 314, 3681, 603, 40, 2757, 1995, 434, 31, 182, 1977, 0, 17, 6],
#  [143, 12, 1250, 3, 2205, 0],
#  [634, 178, 0, 4148, 179, 0, 0, 362, 0, 17],
#  [4639, 2, 818, 2],
#  [71, 438, 438, 71],
#  [286, 0, 2990, 801, 212, 2587, 480, 336, 571, 19],
#  [427, 4965, 765, 74],
#  [0, 299, 514, 102],
#  [0,
#   64,
#   4640,
#   0,
#   40,
#   0,
#   4149,
#   814,
#   163,
#   986,
#   0,
#   2352,
#   384,
#   3423,
#   0,
#   2036,
#   292],
#  [298, 160, 939, 1888, 121, 640],
#  [603,
#   213,
#   130,
#   448,
#   498,
#   420,
#   465,
#   228,
#   4842,
#   0,
#   0,
#   2,
#   307,
#   0,
#   61,
#   3077,
#   54,
#   173,
#   1319,
#   4843,
#   3077,
#   192,
#   0,
#   0],
#  [579, 0, 148, 1023, 25, 4433, 752, 25, 2535, 223],
#  [3993,
#   787,
#   674,
#   72,
#   460,
#   21,
#   615,
#   876,
#   421,
#   0,
#   0,
#   96,
#   4966,
#   0,
#   0,
#   0,
#   0,
#   4966,
#   0,
#   542,
#   0,
#   615,
#   63,
#   7,
#   44,
#   0,
#   574,
#   0,
#   0,
#   0,
#   15,
#   0,
#   145],
#  [0,
#   4534,
#   6,
#   2683,
#   1147,
#   388,
#   1353,
#   2,
#   0,
#   2,
#   2400,
#   241,
#   0,
#   0,
#   0,
#   641,
#   0,
#   0,
#   0,
#   316,
#   0,
#   337,
#   0,
#   0,
#   2991,
#   0,
#   4535,
#   1403],
#  [0, 3762, 96, 0, 3762, 96],
#  [150, 763, 943],
#  [0, 316, 324, 105, 789, 373],
#  [118, 0, 551, 0, 249, 501, 0, 0, 0, 24, 2559, 392],
#  [0, 0, 4738, 3682, 0, 0, 0, 42],
#  [243, 333, 765, 3915, 9, 0],
#  [0, 117, 396, 47, 3188, 27],
#  [580, 1776, 0, 3132, 171, 386, 581, 120],
#  [1823, 1430, 3683, 1950, 40, 20, 0],
#  [287, 0, 502, 0, 2037, 2037, 51, 0],
#  [52, 290, 328, 0, 10, 472, 1626, 1493, 0, 694, 364, 42],
#  [0, 0, 0, 4641, 2992],
#  [1277, 1187, 36, 660, 3484],
#  [305, 416, 0],
#  [0, 889, 804],
#  [672, 3, 3235, 1627, 1777],
#  [0, 0, 1744, 3763, 1381, 4739, 26, 98, 3279, 1628],
#  [6, 0],
#  [271, 136, 976],
#  [2, 125],
#  [1791, 0, 603, 408, 0, 281, 61],
#  [123, 1704, 360, 0],
#  [2816, 0, 532, 2816, 0, 532],
#  [0, 417, 178],
#  [714, 1036, 1142, 3079, 1036, 1142, 0, 1335, 132],
#  [107, 1703, 17, 75, 4536],
#  [0,
#   0,
#   0,
#   3363,
#   419,
#   54,
#   492,
#   2684,
#   7,
#   1174,
#   1286,
#   1606,
#   3684,
#   7,
#   0,
#   0,
#   143,
#   0],
#  [672, 3, 0],
#  [95, 55, 42, 847, 45, 111],
#  [1364, 1834, 55, 12, 634, 70, 2588],
#  [1621, 594, 0],
#  [3609, 604, 61],
#  [260,
#   33,
#   113,
#   1746,
#   111,
#   3764,
#   2206,
#   2652,
#   0,
#   0,
#   4070,
#   53,
#   260,
#   33,
#   698,
#   1646,
#   0,
#   94,
#   2050,
#   21],
#  [32, 169, 32, 323],
#  [26, 5, 650, 4537, 26, 882, 499],
#  [244, 807, 0, 3033, 4150],
#  [23],
#  [294, 0, 1607, 565, 0, 0],
#  [0],
#  [92, 618, 0, 618],
#  [405, 1365],
#  [315, 59, 0, 1240, 0, 0, 10, 346, 276, 0, 59, 0],
#  [0, 965, 2, 3765, 190, 0, 22, 411, 2181, 1438, 158, 0, 1935],
#  [1117],
#  [4844],
#  [82, 1077, 34, 324, 34, 139, 81, 390, 390, 1608],
#  [2353,
#   1522,
#   117,
#   156,
#   16,
#   21,
#   78,
#   122,
#   2182,
#   4434,
#   0,
#   0,
#   31,
#   1778,
#   1031,
#   2993,
#   0,
#   78,
#   308,
#   1037,
#   0,
#   2457,
#   0],
#  [237, 0, 25, 40, 995, 9, 2, 0],
#  [33, 4151, 863, 1203, 2151, 42, 11, 1074, 311, 174, 169],
#  [736,
#   0,
#   0,
#   165,
#   8,
#   11,
#   0,
#   330,
#   150,
#   165,
#   348,
#   229,
#   2279,
#   70,
#   0,
#   1219,
#   111,
#   8,
#   671,
#   0,
#   671,
#   0,
#   0,
#   4845,
#   14],
#  [10, 238, 0, 49, 0],
#  [1532],
#  [329, 54, 2993, 3916, 363, 3830, 0, 295, 1856, 129, 260],
#  [491, 491],
#  [5, 877, 1579, 440, 20, 37, 0, 0, 485, 36, 0, 1508, 1835],
#  [208, 3080, 0, 0, 710, 1404, 2458],
#  [3,
#   1241,
#   112,
#   0,
#   864,
#   2183,
#   3485,
#   224,
#   818,
#   0,
#   0,
#   818,
#   13,
#   94,
#   112,
#   146,
#   431,
#   38,
#   75,
#   465,
#   0,
#   0,
#   0,
#   0,
#   0,
#   315,
#   855,
#   0],
#  [0, 6],
#  [0, 96, 616, 0, 153, 0],
#  [24,
#   3031,
#   489,
#   134,
#   0,
#   0,
#   0,
#   411,
#   0,
#   0,
#   0,
#   1344,
#   326,
#   0,
#   419,
#   0,
#   0,
#   458,
#   92,
#   0,
#   259,
#   4967],
#  [444, 2898, 51, 468],
#  [28, 977],
#  [31, 329, 1108, 44, 1857, 2, 0, 153, 2375, 1030, 1326, 0, 242, 1733, 0, 4740],
#  [1311, 806, 60, 0],
#  [1287, 12, 608, 0],
#  [2480, 2, 221, 0, 4435, 1479, 3236, 3486, 47, 2480, 2, 0],
#  [118, 2376, 3487, 408, 205, 412, 0, 1345, 278, 4331, 45, 2152],
#  [829,
#   67,
#   2225,
#   3917,
#   266,
#   829,
#   105,
#   10,
#   1336,
#   3189,
#   120,
#   9,
#   69,
#   3766,
#   490,
#   129,
#   0,
#   27,
#   1469,
#   137],
#  [3678, 736, 0, 0, 0, 403],
#  [913, 467, 0],
#  [0, 204, 0, 3831],
#  [150, 0, 1230, 0, 4, 39, 0, 1916, 0, 2654],
#  [313, 36, 1439, 0, 2940],
#  [15, 1327, 0, 440],
#  [125, 507],
#  [147, 7, 282, 6],
#  [621,
#   1380,
#   270,
#   0,
#   33,
#   0,
#   320,
#   0,
#   544,
#   0,
#   662,
#   621,
#   402,
#   621,
#   263,
#   13,
#   14,
#   443,
#   29],
#  [2050, 1792, 0],
#  [1836, 17, 0, 3280, 0, 1509, 2427, 0],
#  [3488, 0, 10, 0, 0, 81, 390, 390, 745, 10, 705, 0, 28, 162, 39, 92, 19, 779],
#  [147, 0, 708, 4436, 3685, 334, 321, 1747, 148, 4071, 0],
#  [0, 0, 48, 0],
#  [312,
#   747,
#   1082,
#   211,
#   0,
#   444,
#   0,
#   65,
#   2428,
#   0,
#   225,
#   0,
#   338,
#   0,
#   0,
#   225,
#   0,
#   0,
#   0,
#   0,
#   209],
#  [127, 910, 1391],
#  [412, 572, 18, 480, 2110, 0, 175, 222],
#  [1647, 0],
#  [0, 317, 0, 0, 67, 210, 149, 2501, 108, 0, 128, 508, 2, 590, 0],
#  [1978,
#   846,
#   1082,
#   99,
#   0,
#   0,
#   37,
#   0,
#   590,
#   372,
#   0,
#   4236,
#   9,
#   57,
#   0,
#   2,
#   0,
#   59,
#   256,
#   160],
#  [3543, 609, 1541, 12, 2017],
#  [4741, 18, 514, 2184, 2, 4152, 645, 9, 1996, 2153, 0],
#  [0, 2226],
#  [3610, 378, 617, 1470, 0, 1203],
#  [0],
#  [3318, 1648, 0, 0, 0],
#  [35, 304, 274, 790, 5, 1251, 3994],
#  [23, 500, 1118, 2354, 3767, 124, 746],
#  [3686, 3544, 997, 1935, 16, 490, 732],
#  [0],
#  [3918, 65, 213, 272, 370, 339, 889, 1043, 45],
#  [0, 834, 0, 1194, 0, 10, 3237, 2309, 1057],
#  [0, 1153, 4437, 0, 3133, 0, 1134, 3995, 1044],
#  [313, 367, 1510],
#  [2182, 0, 8, 555, 27],
#  [446, 1414, 132, 1459, 4, 29],
#  [1746],
#  [10, 500, 112, 0, 110],
#  [2685, 2111, 0, 1220, 1337, 1494, 2282, 270, 95, 1671, 140, 494, 64, 365],
#  [1629, 200, 669, 0, 0, 0, 834, 1088, 357],
#  [3028, 99, 0, 0, 206, 884, 107, 0, 0],
#  [35, 66, 664, 723, 0, 319, 863, 0, 597],
#  [1495, 9, 0, 337, 161],
#  [533, 46, 0, 308, 0, 503, 30, 111],
#  [289, 10, 334, 3238, 0, 0, 0, 1680, 0, 829, 4237, 2899, 1748, 0, 1748, 171],
#  [0,
#   2185,
#   0,
#   0,
#   0,
#   0,
#   0,
#   3365,
#   521,
#   0,
#   4,
#   0,
#   559,
#   0,
#   16,
#   2560,
#   0,
#   831,
#   556,
#   0,
#   2655,
#   0,
#   0,
#   0,
#   521,
#   2820,
#   0,
#   0,
#   0,
#   1686,
#   27,
#   0,
#   0,
#   0,
#   2589],
#  [774, 70, 2459, 0, 0, 0, 3239, 74, 127, 243],
#  [981],
#  [672],
#  [178, 117, 26, 156, 26, 78, 145],
#  [0, 17, 65, 0, 0, 0],
#  [36, 188],
#  [0, 17, 1312, 83, 2401, 0, 220, 0, 83, 0, 2721],
#  [9, 2, 939, 244, 1231, 161],
#  [0, 0, 0, 1051, 0, 0, 0, 0, 885, 0, 288, 0, 873],
#  [101],
#  [26, 463, 57, 0],
#  [0, 0, 109, 2184, 0],
#  [1278, 90, 155, 0, 1382],
#  [3543, 17, 3034, 2309, 791, 807, 0, 41, 23],
#  [280, 11, 4],
#  [0, 0, 4153, 119, 2051, 296, 710],
#  [466, 3768, 409, 1609, 0, 49, 0, 331, 2481, 0, 152],
#  [235,
#   14,
#   2310,
#   161,
#   2186,
#   3424,
#   119,
#   647,
#   0,
#   367,
#   594,
#   0,
#   0,
#   1436,
#   13,
#   141,
#   1204,
#   17,
#   1405,
#   2632,
#   141,
#   3,
#   3687,
#   0],
#  [203,
#   0,
#   2052,
#   97,
#   2250,
#   775,
#   2324,
#   0,
#   651,
#   1672,
#   400,
#   44,
#   22,
#   2283,
#   3190,
#   1152,
#   0,
#   0,
#   0,
#   51,
#   2377,
#   413,
#   0,
#   0,
#   668],
#  [393, 787, 990, 15, 3281, 0, 217, 1097],
#  [1328, 0, 87, 279, 972, 353, 289, 87, 1718, 0, 129, 278, 564, 4, 7, 2758],
#  [3489, 4538, 0, 119, 1449],
#  [422,
#   0,
#   557,
#   412,
#   0,
#   278,
#   59,
#   539,
#   12,
#   465,
#   122,
#   826,
#   784,
#   238,
#   0,
#   747,
#   12,
#   0,
#   1659,
#   1576,
#   299,
#   0,
#   213,
#   200,
#   0,
#   412,
#   1858,
#   0,
#   63],
#  [0, 0, 0, 173, 0, 0, 675, 3832, 0],
#  [1154, 3611, 0, 281, 2853],
#  [395, 3764, 0, 3996, 148, 0, 0, 63],
#  [590, 0, 0, 0, 1431, 198, 127, 4067, 2092],
#  [0, 383, 0, 37, 1917, 551, 0, 602, 529, 47, 3035, 1871],
#  [191, 107, 5, 3319, 3425],
#  [555, 442, 14, 161],
#  [2686, 977, 564, 0, 187, 2941, 2072, 0],
#  [0, 0, 443, 623],
#  [4968, 0, 562, 179, 532],
#  [0, 114, 264, 627, 479, 152],
#  [522,
#   513,
#   3545,
#   522,
#   1687,
#   4154,
#   163,
#   642,
#   13,
#   0,
#   521,
#   386,
#   130,
#   586,
#   25,
#   37,
#   112,
#   1951,
#   33,
#   483,
#   3134,
#   0,
#   416,
#   3833,
#   0,
#   2560,
#   0,
#   0,
#   1175,
#   0,
#   0,
#   217,
#   0,
#   0],
#  [3426, 697, 2561, 1997, 2502, 0],
#  [167],
#  [144, 158],
#  [3320, 0, 25, 40, 0, 0, 21, 220, 184, 1344, 521, 828, 0, 331, 0, 0],
#  [0, 115, 213, 189, 18, 139, 4069, 0, 3427, 8],
#  [1366, 98, 3834, 119, 133, 273],
#  [0, 627, 1045, 39, 133, 986, 2942, 2942, 0, 1038, 131, 591, 0, 40, 1688],
#  [3688, 214, 431, 0, 0],
#  [5, 32, 676, 337, 0, 17, 878, 11, 728, 4642, 0],
#  [11, 1449, 1449],
#  [530,
#   0,
#   1037,
#   4072,
#   226,
#   0,
#   156,
#   12,
#   222,
#   65,
#   2429,
#   73,
#   344,
#   1286,
#   0,
#   4073,
#   56,
#   219,
#   65,
#   0,
#   1626],
#  [665, 3081, 4742, 1104, 4, 32],
#  [67, 198, 834, 128, 184, 821, 2935, 420, 341, 80, 64, 1077, 0, 851],
#  [0, 854, 254, 72, 0, 183, 0],
#  [47, 0, 47, 137, 29, 4531],
#  [0],
#  [4539, 0, 0, 1296, 830, 0],
#  [0, 3608, 0, 3835, 2990, 268, 873],
#  [4074, 0, 0, 0, 668],
#  [998, 28],
#  [35, 2378, 325, 441, 85, 3836, 3546],
#  [],
#  [114, 252, 2053, 256, 0, 20, 3612],
#  [277, 79, 492],
#  [0, 2633, 141],
#  [125, 108, 0],
#  [58,
#   152,
#   453,
#   1159,
#   0,
#   0,
#   287,
#   0,
#   4075,
#   0,
#   808,
#   0,
#   0,
#   2502,
#   785,
#   289,
#   138,
#   152,
#   617,
#   16,
#   35,
#   170,
#   961,
#   4969,
#   148,
#   0,
#   896,
#   0,
#   0,
#   152,
#   453,
#   711,
#   680,
#   526,
#   537,
#   756,
#   1363],
#  [38, 1402, 38, 2, 38, 416, 178],
#  [0, 4540, 0],
#  [],
#  [2994, 7, 0],
#  [4],
#  [490,
#   3321,
#   238,
#   0,
#   447,
#   0,
#   0,
#   0,
#   26,
#   0,
#   61,
#   2284,
#   3191,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   4155,
#   3036,
#   0,
#   29,
#   238,
#   1117],
#  [0],
#  [1195, 1055, 3547, 1195, 148, 575, 65, 0],
#  [11, 280],
#  [324,
#   355,
#   1279,
#   1303,
#   22,
#   31,
#   2995,
#   1123,
#   0,
#   634,
#   2429,
#   0,
#   0,
#   314,
#   4970,
#   1749,
#   0,
#   230,
#   31,
#   0,
#   3997,
#   0,
#   0,
#   164,
#   0,
#   279,
#   0,
#   2430,
#   0,
#   706,
#   0,
#   0,
#   4156],
#  [201, 799, 387, 799, 155],
#  [886, 1045, 886],
#  [1252, 1663],
#  [0, 65, 2093, 0, 80],
#  [13],
#  [1664, 0, 1705, 0, 458, 100, 0, 458, 2536, 59, 4076, 0, 0, 716, 1188],
#  [0, 0, 2, 0],
#  [196, 2112, 0, 12, 222, 2094, 7, 1566],
#  [1209, 1189, 0, 0, 220],
#  [113, 3490],
#  [0, 12, 44, 225, 1824, 0, 0],
#  [300, 673, 3613, 0, 1900, 1719, 3280, 1109, 425],
#  [3192, 631, 4077, 631, 106, 0],
#  [283, 68, 3548],
#  [285, 0, 1745, 0, 40, 982, 172],
#  [4, 686, 28, 0, 2687, 2, 719],
#  [255, 50],
#  [0,
#   322,
#   2590,
#   22,
#   3689,
#   2591,
#   0,
#   0,
#   504,
#   1799,
#   160,
#   1329,
#   105,
#   0,
#   0,
#   0,
#   3998,
#   0,
#   22,
#   0,
#   3999],
#  [158],
#  [2537, 752, 1392, 160, 11, 3322, 0, 266],
#  [14, 0, 2154, 92, 2187],
#  [9, 697, 2, 1075, 0, 103, 0, 701, 1211, 719],
#  [3082, 2996, 113, 1746, 0, 0, 157, 535, 582, 93],
#  [996, 0, 0, 393, 862, 2325, 1196, 223, 1404, 324, 0, 0, 324, 0, 0, 0, 1404],
#  [328, 1270, 3614, 1077, 3193],
#  [2326, 1621, 4971, 135, 3615, 433, 0, 0, 8],
#  [101, 0, 14, 1749, 31, 1673],
#  [0, 69, 2431, 3837, 163, 113, 158, 429, 19, 0, 1889],
#  [76, 512, 183, 39, 334],
#  [1606, 222, 0, 17],
#  [0, 1176, 33, 453, 592, 78, 1511, 0, 4157, 2375, 1872, 228, 0, 42],
#  [1160, 67, 3491, 32, 0, 77],
#  [0,
#   3549,
#   0,
#   0,
#   1103,
#   0,
#   80,
#   20,
#   105,
#   789,
#   132,
#   3077,
#   1344,
#   20,
#   64,
#   3549,
#   648,
#   0,
#   22,
#   326,
#   0,
#   74,
#   1423,
#   0,
#   0],
#  [4643, 3616, 707, 1060, 3769],
#  [7],
#  [213, 98, 0, 2207],
#  [2073,
#   263,
#   362,
#   77,
#   62,
#   16,
#   351,
#   62,
#   4964,
#   0,
#   0,
#   132,
#   9,
#   66,
#   664,
#   95,
#   457,
#   1471],
#  [1998, 3135, 255],
#  [3, 760, 184, 0, 42],
#  [914, 59, 2208, 2688, 67, 854],
#  [166, 370, 0],
#  [0, 220, 22, 4438, 0, 681, 0],
#  [12, 17, 0, 0, 869, 962, 153],
#  [2155, 2719, 3136, 592, 2, 0, 414, 246, 4433, 2997],
#  [7, 7, 7, 0],
#  [580,
#   0,
#   1124,
#   0,
#   1089,
#   1496,
#   0,
#   1594,
#   4846,
#   370,
#   1594,
#   0,
#   1362,
#   4332,
#   4847,
#   63],
#  [997, 0, 0, 0, 1720, 997, 209, 0, 152],
#  [213, 115, 364, 2372, 2248, 36, 2562, 8],
#  [4],
#  [2538, 0, 43, 943, 4848, 0, 3282, 0, 1627, 2793, 279, 124, 616, 0, 2],
#  [],
#  [263, 43, 2, 389, 0, 68, 188, 379, 1242, 556, 2074, 0],
#  [2072, 0, 2134],
#  [467,
#   0,
#   0,
#   0,
#   148,
#   0,
#   0,
#   228,
#   489,
#   2251,
#   0,
#   250,
#   1936,
#   3919,
#   489,
#   1158,
#   0,
#   466,
#   466,
#   0,
#   0,
#   76,
#   0,
#   159,
#   69,
#   6,
#   20,
#   0,
#   68,
#   2251,
#   0],
#  [4743, 93, 376, 0, 760, 1610, 13, 3083, 44, 1197, 3838],
#  [2943, 2900, 1304, 103, 0, 360, 0],
#  [0, 517, 148, 1109, 359, 164, 0, 4078, 847],
#  [0, 508, 0, 3037, 0],
#  [0, 1800, 251, 655],
#  [312, 89, 0, 0, 59, 0, 1665, 529],
#  [4000, 0, 474, 0],
#  [0, 2, 1393, 36, 415, 0, 0, 293, 0, 17],
#  [730, 596, 33, 819, 100, 0, 4541, 3323, 0, 63, 97, 3038, 0, 0],
#  [453, 1147, 55, 1198],
#  [22, 0, 377, 4, 8, 0, 0, 2018, 29],
#  [0],
#  [507, 0, 4, 0, 640, 4],
#  [15, 3770, 3194, 3324],
#  [1291, 1118, 860, 0, 3839, 78],
#  [4849],
#  [197,
#   12,
#   2250,
#   140,
#   12,
#   44,
#   378,
#   260,
#   1098,
#   33,
#   0,
#   582,
#   0,
#   4840,
#   3690,
#   50,
#   388,
#   0,
#   206,
#   35,
#   610,
#   715,
#   1686,
#   33,
#   195,
#   1873,
#   3425,
#   340,
#   2075,
#   555],
#  [4238, 0, 444, 0, 1391],
#  [4428, 1440],
#  [47, 45, 45],
#  [4079, 3428, 134, 927, 2252, 927, 1088, 357],
#  [11, 1901, 875, 13, 1595, 145, 107, 302, 0],
#  [11, 328, 0, 4158, 0, 13, 0, 1825, 0, 0, 328, 0, 0, 40, 2253, 92, 302, 4744],
#  [350, 7],
#  [0, 54, 69, 1110, 0],
#  [2327, 2019, 3, 570, 1937, 1197],
#  [2430, 2460, 966, 1186],
#  [1596, 1874, 0, 96],
#  [444, 2590, 724, 0, 2632, 2854, 180, 0, 701, 1211, 0],
#  [0, 2539, 467, 783, 0, 0, 531, 0],
#  [317, 1017, 0],
#  [295, 143, 1078, 4542, 3084, 1826, 2355, 3550, 0, 16],
#  [519, 1542, 327, 838, 0, 1076, 604],
#  [166, 3551, 388, 68, 672, 519, 0, 1403, 1252, 4745],
#  [43,
#   2,
#   127,
#   198,
#   4850,
#   742,
#   3283,
#   796,
#   0,
#   0,
#   79,
#   1767,
#   639,
#   861,
#   879,
#   0,
#   3840,
#   0,
#   147,
#   1567,
#   0,
#   1346,
#   3492,
#   573,
#   0,
#   1494,
#   143,
#   886],
#  [3,
#   0,
#   387,
#   0,
#   1406,
#   0,
#   46,
#   1366,
#   2135,
#   0,
#   747,
#   81,
#   0,
#   1045,
#   1090,
#   93,
#   757,
#   674,
#   1292,
#   180,
#   0,
#   0],
#  [150, 3, 0, 1099],
#  [2634, 0, 3691, 2901, 155, 0, 193, 0, 0, 856, 0, 0, 0, 464],
#  [3920, 2656, 1082, 456, 933, 618, 0, 0, 809, 66, 0, 0, 0],
#  [1689],
#  [788, 3325, 920, 343, 390, 1801],
#  [762, 80, 1061, 155, 0],
#  [39, 48, 2076, 0, 224, 63, 8, 2077, 724, 765, 74, 10, 29],
#  [0, 4, 0],
#  [0, 810, 868, 224, 74, 5, 875, 2501, 44, 432, 2402],
#  [14, 0, 0, 294, 108, 0, 0, 294, 0, 2037, 2503, 1456, 1327, 2592, 0, 427],
#  [11, 12, 1367, 28],
#  [1365, 1365],
#  [2052, 0, 1030, 2113, 0, 3085, 0],
#  [157, 9, 346, 59, 260],
#  [11, 622, 0],
#  [665, 0, 0, 0, 0],
#  [0, 0, 1415, 0, 2180],
#  [1190],
#  [1111, 2209, 90, 2635, 4637, 725, 4333, 83, 690, 112, 64, 4148, 179, 237],
#  [878],
#  [496, 50, 158],
#  [0, 0, 317, 27],
#  [298, 298, 365, 1721, 0, 4334, 12, 120],
#  [758, 2789, 111, 0, 1576, 1659, 0, 138, 53, 887, 88, 78],
#  [4543, 445, 3841, 79, 181, 3080, 1523],
#  [852, 18, 50, 214, 1793, 4],
#  [117, 90, 18, 0, 85, 0, 1142, 669],
#  [0, 1837, 0, 1580, 962, 2855, 64, 2379],
#  [2278, 835, 1018, 2, 33, 2],
#  [1496,
#   2848,
#   40,
#   0,
#   0,
#   532,
#   100,
#   0,
#   0,
#   0,
#   10,
#   69,
#   3493,
#   3921,
#   128,
#   0,
#   1497,
#   0,
#   238,
#   43,
#   128,
#   572,
#   0,
#   0,
#   9,
#   113,
#   0],
#  [819, 16, 137, 9, 13, 106, 0],
#  [0, 2848, 67, 0, 144, 934],
#  [2504, 19, 375, 1973, 2504, 1952, 326, 3429],
#  [1915, 0, 0, 29, 2505, 0, 329, 54, 991, 9, 0],
#  [52,
#   351,
#   0,
#   53,
#   8,
#   1706,
#   209,
#   215,
#   66,
#   664,
#   4335,
#   2136,
#   0,
#   0,
#   209,
#   51,
#   1626,
#   8,
#   35,
#   4746,
#   5,
#   33,
#   848,
#   329,
#   54,
#   146,
#   2759,
#   333,
#   0,
#   35,
#   29,
#   0,
#   8,
#   121,
#   0,
#   124,
#   435,
#   131,
#   2356,
#   27],
#  [769, 467, 334, 542, 905, 2590, 0],
#  [534, 420, 3430, 753, 0, 0, 0],
#  [685, 3771, 64, 1622, 4439, 1177, 611, 13, 320, 64, 3772, 0],
#  [127, 1779, 47, 4],
#  [0],
#  [47, 257, 86, 0, 905],
#  [310],
#  [166, 317],
#  [67,
#   41,
#   1079,
#   1186,
#   262,
#   545,
#   168,
#   169,
#   183,
#   0,
#   0,
#   6,
#   183,
#   6,
#   25,
#   40,
#   2,
#   43,
#   2506,
#   195,
#   46,
#   1533,
#   31,
#   1029,
#   0],
#  [80, 258, 1532, 502, 0, 0],
#  [4440, 4440],
#  [893, 0, 0, 2020, 1161],
#  [11, 0, 194, 1205, 690],
#  [203, 1902, 335, 1802, 0, 65, 4, 0, 0, 19, 564, 4, 2856, 0, 131],
#  [0, 4159, 0, 1630],
#  [412, 1875, 1918, 375, 0, 613, 1890, 1596, 518],
#  [24, 1132, 657, 17, 0, 1364, 55],
#  [0, 0, 4851, 0, 0, 668],
#  [0, 0, 0],
#  [973, 183, 973, 7, 0, 582, 46, 18, 143, 2353, 0, 30],
#  [0, 967, 3842, 574, 0],
#  [1472, 201, 0, 0, 61, 2425, 117, 1024],
#  [862, 130, 0],
#  [0, 1280, 433, 72, 2078, 145, 1160, 76, 0, 0, 329, 1108, 3039, 14],
#  [23, 67, 0, 43],
#  [0, 433, 492, 145],
#  [423,
#   208,
#   46,
#   617,
#   192,
#   0,
#   279,
#   415,
#   109,
#   67,
#   0,
#   94,
#   963,
#   0,
#   5,
#   1888,
#   1099,
#   163,
#   63],
#  [0,
#   0,
#   23,
#   0,
#   560,
#   0,
#   0,
#   0,
#   1919,
#   1334,
#   3321,
#   57,
#   3137,
#   0,
#   0,
#   4533,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2429,
#   0,
#   41,
#   201,
#   2821,
#   440,
#   0,
#   706,
#   3843,
#   3321,
#   276],
#  [611, 714, 2254, 145, 0, 0, 2432, 0, 0, 0],
#  [1876, 103, 7],
#  [0,
#   687,
#   0,
#   42,
#   87,
#   1228,
#   321,
#   2379,
#   2722,
#   122,
#   0,
#   4852,
#   0,
#   157,
#   1803,
#   9,
#   0,
#   447,
#   277,
#   15,
#   0,
#   42,
#   388,
#   0,
#   274,
#   0,
#   42],
#  [350, 2156, 7],
#  [74, 255, 177, 55, 428, 1562, 193, 363, 1358],
#  [5, 0, 32, 12, 3552, 0],
#  [371, 526, 0, 0, 0, 0, 125],
#  [3031, 0, 1507, 698, 141, 373, 10, 397, 792, 580, 1492, 3494, 25],
#  [1534, 0, 1950, 7, 264],
#  [2255,
#   0,
#   0,
#   2822,
#   115,
#   1253,
#   3195,
#   72,
#   0,
#   270,
#   868,
#   1671,
#   0,
#   10,
#   673,
#   0,
#   344,
#   999,
#   0,
#   631],
#  [258, 0, 514],
#  [],
#  [20, 1100, 0, 2636, 3692, 524, 766],
#  [203, 1902, 0, 817, 1279, 30, 759, 637, 0],
#  [4, 297, 3284, 2184],
#  [187, 72, 3612],
#  [180, 208, 1473, 2090, 3922, 1664, 515],
#  [480, 0, 0, 42],
#  [2285, 3285, 0, 76, 87, 51, 1167],
#  [0, 635, 0, 0, 0, 208, 291, 1820, 0],
#  [],
#  [3321, 1374, 0, 79, 0, 759, 0],
#  [1110, 141, 0, 0],
#  [418, 0, 659, 75],
#  [28, 3086, 0, 355, 611, 686, 28, 22, 89, 2433, 136, 0, 151, 205, 3087],
#  [0, 976, 1068, 126, 144, 2095, 3923],
#  [0,
#   2990,
#   32,
#   3495,
#   3240,
#   59,
#   3431,
#   522,
#   513,
#   522,
#   513,
#   0,
#   513,
#   165,
#   119,
#   2998,
#   408,
#   16,
#   12,
#   1877],
#  [2079, 0, 627],
#  [914, 4, 391, 71, 0, 580, 2133, 904, 40],
#  [65, 4],
#  [88, 899],
#  [295,
#   1480,
#   71,
#   1674,
#   9,
#   0,
#   1999,
#   3196,
#   86,
#   0,
#   1347,
#   0,
#   0,
#   1069,
#   453,
#   0,
#   2054,
#   4747,
#   1178],
#  [337, 0, 171, 3844, 1568, 0, 0, 0],
#  [41, 347, 61],
#  [1053, 0, 46, 0, 30, 0, 0, 14, 376, 178],
#  [203, 112, 149, 255, 31, 2328, 0, 1140, 218, 2114, 609, 43, 223, 1168, 146],
#  [962, 2855, 0, 197],
#  [949, 987, 0, 243, 1135, 0],
#  [0,
#   3924,
#   16,
#   3,
#   3687,
#   51,
#   3773,
#   554,
#   52,
#   743,
#   30,
#   431,
#   0,
#   0,
#   0,
#   295,
#   1383,
#   0,
#   66,
#   139,
#   295,
#   0,
#   0,
#   2055],
#  [0, 872],
#  [23, 9, 1827, 19, 2563],
#  [492, 1793, 4234, 1405, 815, 4, 686, 126, 11, 0, 0, 0, 4544, 615, 479],
#  [0, 195, 0, 3241],
#  [13, 77, 302, 2000, 1533, 12, 2286],
#  [36, 0, 0, 31, 8],
#  [0, 1179, 29],
#  [15],
#  [3492, 977, 0, 0, 328, 0, 89, 0, 3138, 0, 0, 977, 3492, 938],
#  [412, 1251, 36, 253, 55, 35],
#  [405, 0, 21],
#  [65, 4, 0, 228, 0, 0, 59],
#  [10, 42, 2564, 0],
#  [0, 0, 2434, 469, 94, 512],
#  [598, 4441, 419, 944, 0, 0, 2999, 0, 1037, 0, 0, 2151],
#  [1054, 23, 66, 2565, 568, 213, 1750, 508, 3197, 0, 0, 72, 460, 986, 0, 8],
#  [4545, 423, 0, 701, 3198],
#  [1079, 0],
#  [],
#  [38, 1878],
#  [41, 104],
#  [4848, 0, 1953, 0, 351, 2380, 246],
#  [0, 1343, 299, 0, 28, 2902, 0, 169, 0],
#  [0, 50, 214, 0, 0, 2, 4972, 0, 133, 2227, 8],
#  [0, 242, 0, 996, 2176, 2327, 0, 0, 164, 251, 0, 0],
#  [260, 793, 3693, 2114, 32, 174, 39, 193, 4160, 273],
#  [],
#  [0, 0],
#  [101, 3, 1780, 4001, 4080, 63],
#  [4644, 0, 1305, 330, 2287, 8, 0, 3418, 0],
#  [118, 4161, 56, 142, 748],
#  [24,
#   392,
#   623,
#   714,
#   1416,
#   714,
#   387,
#   1271,
#   0,
#   1348,
#   1346,
#   122,
#   24,
#   0,
#   1354,
#   300,
#   193,
#   2944,
#   399,
#   42,
#   36,
#   253,
#   18,
#   55,
#   136,
#   413,
#   3617,
#   4002,
#   0,
#   0,
#   1781,
#   145],
#  [81, 390, 4336, 0, 162, 1290, 0],
#  [0, 666],
#  [258, 0, 1019, 0, 0, 2657, 2403, 0, 3432, 619, 524],
#  [0, 3845, 629, 30, 36, 188, 2461, 2157],
#  [178, 285, 0, 2822, 0, 4081, 44, 184, 896, 0, 2051, 26, 0],
#  [349, 0, 135, 665, 1422, 80, 0, 0],
#  [8, 0, 2945, 2228, 707, 633, 21, 110],
#  [101, 0, 298, 587, 457],
#  [1242, 0, 665, 0, 0, 2723, 4853, 3846, 291, 0],
#  [144, 250, 7],
#  [0, 0, 72, 150, 0, 3195, 189, 0, 1099],
#  [0,
#   230,
#   0,
#   277,
#   218,
#   1125,
#   3190,
#   677,
#   0,
#   0,
#   1232,
#   596,
#   1535,
#   404,
#   822,
#   126,
#   1242,
#   0,
#   4239,
#   427,
#   3847,
#   207,
#   157,
#   0,
#   10,
#   19,
#   100,
#   1125,
#   0,
#   0,
#   0],
#  [26, 7, 28, 0, 58, 4240, 61],
#  [2686, 289, 0, 89, 0, 401],
#  [0, 0, 1000, 135, 196, 89, 27],
#  [1707, 171, 346, 0],
#  [1903, 1879, 25, 0, 868, 0, 0, 43],
#  [2325, 0, 34, 139, 671, 2823, 2154, 0, 598, 1631, 181],
#  [9, 113, 55, 48, 1169, 55],
#  [229, 99],
#  [312, 144, 409, 102],
#  [4, 22, 82, 190, 2724, 2462, 17, 114, 3496, 0, 94, 0, 1450, 675, 114, 256],
#  [164, 4003, 3848, 0],
#  [1057, 0, 4854, 0, 157, 431, 2996, 216],
#  [],
#  [0, 139, 114, 256],
#  [3040, 1355, 345, 0, 21, 2001, 1734, 1151],
#  [13, 91, 4442, 373, 2183, 0, 0, 906, 1199, 0, 2137],
#  [4546,
#   977,
#   2939,
#   678,
#   87,
#   386,
#   0,
#   2685,
#   1675,
#   0,
#   1143,
#   0,
#   1338,
#   641,
#   2857,
#   431,
#   0,
#   0,
#   3139,
#   292,
#   65,
#   1920,
#   469,
#   4645,
#   66,
#   630,
#   332],
#  [141, 1428, 733, 44],
#  [3, 0, 3849, 466, 0, 1979, 3199],
#  [37, 1859, 782, 2158, 1306, 533, 0, 132, 0, 0, 0, 7, 1859, 834, 60],
#  [101,
#   0,
#   232,
#   0,
#   0,
#   2019,
#   3924,
#   0,
#   383,
#   1269,
#   0,
#   353,
#   335,
#   172,
#   168,
#   3486,
#   395,
#   980,
#   0,
#   40,
#   1257,
#   40,
#   0,
#   0,
#   0,
#   2080,
#   213,
#   0],
#  [198, 686],
#  [0, 0],
#  [340, 1722, 0, 835, 978, 702, 0, 2794, 2403, 1394, 132, 0],
#  [40],
#  [1061, 2482, 309, 57, 2136],
#  [214, 1359, 1891, 0, 20, 0, 1680, 166, 23, 615, 281],
#  [35, 15, 0, 673, 110],
#  [3200, 0],
#  [0, 206, 1020],
#  [0, 0],
#  [16, 674, 849],
#  [1368, 472, 3140, 6],
#  [92, 1089, 0, 2138, 524, 4, 1076],
#  [3088, 117, 1348, 0],
#  [294, 586, 266],
#  [0, 51, 0, 0, 793, 19],
#  [0, 0, 25, 478, 216, 44, 1278, 90, 1676, 232, 2689, 388, 24, 63],
#  [0, 347, 610, 521, 648, 968, 41, 3917, 443, 197, 197],
#  [0, 0, 0],
#  [0, 0],
#  [1253, 267, 4646, 0, 0, 1837],
#  [137],
#  [11, 0, 4647, 2760],
#  [83, 649, 685, 0, 0, 0, 100, 1751, 599, 1904, 2678, 430, 75, 636, 61],
#  [48, 583, 1367, 101, 48, 911, 55],
#  [36, 472, 1178, 2159, 472, 36, 80, 1388],
#  [1009, 2002, 2593, 21, 0, 2903, 1009, 2002],
#  [654, 0, 804],
#  [247, 2001, 0, 26, 0, 60, 859, 145],
#  [819, 384, 896, 0, 0, 819, 2690],
#  [3774, 4, 0],
#  [0, 12, 0, 0, 0, 0, 0, 0],
#  [193, 253, 226, 1478, 0, 322],
#  [0, 0, 278, 73, 0],
#  [4441,
#   2946,
#   1938,
#   2483,
#   0,
#   0,
#   0,
#   0,
#   4547,
#   2188,
#   0,
#   0,
#   978,
#   0,
#   0,
#   1211,
#   17,
#   2357,
#   237,
#   1939,
#   0,
#   1162,
#   0,
#   33,
#   0,
#   68,
#   106,
#   3430,
#   97,
#   1644,
#   682,
#   353,
#   3694,
#   2463,
#   264,
#   68],
#  [0,
#   855,
#   582,
#   249,
#   0,
#   1649,
#   668,
#   11,
#   1112,
#   417,
#   1334,
#   1112,
#   3925,
#   0,
#   816,
#   367,
#   3925,
#   662,
#   118,
#   279,
#   1424,
#   2288,
#   2288,
#   21,
#   610,
#   0],
#  [685, 3286],
#  [3, 1423],
#  [177, 188, 15, 819, 410, 103],
#  [0,
#   536,
#   0,
#   0,
#   635,
#   0,
#   0,
#   1747,
#   1059,
#   2858,
#   152,
#   3200,
#   3850,
#   0,
#   0,
#   0,
#   707,
#   2038,
#   2358],
#  [0, 119, 35, 28, 231, 0, 0, 1067, 2, 0, 2185, 2210, 121, 0],
#  [113, 1339, 2540, 0, 0, 599, 132, 0, 0, 0, 2, 794, 365],
#  [3366, 4082, 0, 0, 0, 0, 3773, 0, 0, 238],
#  [9, 55],
#  [21, 1521],
#  [60,
#   216,
#   0,
#   1025,
#   0,
#   1070,
#   0,
#   3041,
#   4438,
#   0,
#   0,
#   230,
#   1684,
#   0,
#   1054,
#   0,
#   0,
#   844,
#   564,
#   1144,
#   2594,
#   1880],
#  [3367, 589, 2725, 58, 0, 8],
#  [523, 34, 0, 122, 0, 0],
#  [447, 354],
#  [10, 1296, 830, 0, 2211, 0, 355, 4, 1046],
#  [12, 608, 3201],
#  [0, 61],
#  [150,
#   0,
#   0,
#   0,
#   4237,
#   0,
#   655,
#   0,
#   373,
#   10,
#   0,
#   935,
#   192,
#   0,
#   334,
#   0,
#   343,
#   0,
#   859,
#   0,
#   0,
#   6,
#   441,
#   0,
#   124,
#   436,
#   4162,
#   3141,
#   10,
#   69,
#   0],
#  [0, 3695, 0, 234, 1690, 138, 37],
#  [1936, 151, 2133, 0, 4748, 1973],
#  [23],
#  [380, 1555, 0, 331, 12],
#  [0, 0, 0, 0],
#  [10, 0, 0, 4851],
#  [1212, 0, 8],
#  [374],
#  [85, 1243],
#  [5, 679, 1611, 9, 2, 292, 633, 21, 525],
#  [65, 4, 1384],
#  [20,
#   226,
#   1200,
#   1340,
#   573,
#   1167,
#   205,
#   2256,
#   31,
#   1581,
#   4973,
#   1935,
#   0,
#   4648,
#   53,
#   88],
#  [232, 2289, 3924, 355, 0],
#  [372, 863],
#  [1612,
#   0,
#   0,
#   0,
#   982,
#   213,
#   1498,
#   3679,
#   1536,
#   0,
#   0,
#   0,
#   0,
#   3553,
#   0,
#   4236,
#   3926,
#   0,
#   0,
#   3679,
#   0,
#   0,
#   829,
#   0,
#   2212,
#   1150,
#   643,
#   0,
#   192,
#   0,
#   2308],
#  [11, 368],
#  [484, 916, 176, 983, 2459, 3, 581, 1313, 403, 788, 4163, 1722, 27],
#  [489, 1158, 159, 69, 290, 0, 0, 0, 2857, 467, 0, 874, 1010, 6, 197, 111],
#  [0, 1023, 676, 0, 659, 0, 3202, 232, 16, 0, 160, 319],
#  [1360, 15, 2507, 6],
#  [428, 48, 360, 0, 3849, 0, 570, 622, 2435],
#  [1512, 0, 0, 3368, 0, 0, 0],
#  [1524, 4649, 1422, 205, 1126, 86, 220, 448, 1134, 292, 3851],
#  [3554, 940, 0, 996, 0, 0, 628],
#  [0, 0, 0, 0, 155, 0, 232, 1592],
#  [1375, 1046],
#  [519, 0, 45, 0],
#  [701,
#   1211,
#   1229,
#   9,
#   719,
#   185,
#   0,
#   49,
#   21,
#   560,
#   719,
#   25,
#   80,
#   1047,
#   0,
#   0,
#   4,
#   3369,
#   4],
#  [4974, 0, 2722, 4974, 3089, 262],
#  [167, 608, 68],
#  [3,
#   0,
#   84,
#   0,
#   2761,
#   2206,
#   1288,
#   767,
#   0,
#   3555,
#   33,
#   0,
#   1881,
#   0,
#   0,
#   92,
#   59,
#   0,
#   2566,
#   237,
#   87,
#   279,
#   0,
#   695,
#   160,
#   0,
#   0,
#   0,
#   0,
#   146],
#  [197, 6, 3242, 0, 122, 961, 1244, 0],
#  [0, 2484, 131, 839, 691],
#  [0, 977],
#  [32, 26, 207, 0, 153, 0, 1510],
#  [3142, 0, 0, 0, 109],
#  [1644, 4548],
#  [0, 37, 781, 95, 0, 1650, 0, 2257, 0, 380, 440, 0, 1011, 2152],
#  [1651, 1385, 1677, 56, 219],
#  [3000, 368, 206, 38],
#  [12, 222, 116, 371, 0, 954],
#  [0, 2189, 447, 2329, 1940, 2436, 0, 2160, 0],
#  [2398, 79, 0, 1950, 40, 375, 0, 1140, 461, 696, 3139, 1441],
#  [268, 76, 4241, 741, 46, 18, 1197, 710],
#  [717,
#   161,
#   1781,
#   717,
#   0,
#   690,
#   717,
#   0,
#   0,
#   1880,
#   2115,
#   0,
#   0,
#   3241,
#   717,
#   1101,
#   91,
#   832,
#   161,
#   1021,
#   1835,
#   34,
#   161,
#   0,
#   0,
#   207,
#   519,
#   2381,
#   1556,
#   1794],
#  [663, 1768, 104],
#  [15, 15, 15, 15, 15, 15, 15, 15],
#  [41, 50, 18, 997, 0],
#  [0, 39, 81, 0, 6, 28],
#  [0, 215, 1147, 156, 0, 2353, 473],
#  [1838, 223, 17, 0, 0, 0, 0],
#  [74, 0, 74, 19],
#  [307, 373, 244, 593, 161, 823, 73, 37, 96],
#  [0, 314, 2726, 0, 0, 0],
#  [418, 1823, 222, 0, 936, 22, 60, 1905],
#  [11, 1187, 0, 1251, 1524, 0, 504, 0, 1520, 1649, 2330, 1951, 24, 11],
#  [53,
#   0,
#   2110,
#   149,
#   144,
#   250,
#   0,
#   553,
#   30,
#   2229,
#   250,
#   444,
#   181,
#   1553,
#   0,
#   0,
#   0,
#   28],
#  [3042, 899, 192],
#  [0, 0, 0, 4855, 0, 2567],
#  [3, 1423, 4242, 995],
#  [1163, 627, 391, 0],
#  [144, 0, 827, 0],
#  [4150, 837, 26, 35, 1828],
#  [217, 882],
#  [79, 0, 0, 118, 732, 904, 8],
#  [2049, 0, 1734, 1381, 8],
#  [187, 73, 216, 0, 471, 3143, 1920, 4966, 72, 56, 593],
#  [16, 21, 628, 27, 33, 2],
#  [712, 244, 1838, 4243, 0, 3497, 698, 57, 0, 0, 221, 1036, 0, 0, 237, 613],
#  [],
#  [290, 0, 0, 28],
#  [1920,
#   30,
#   284,
#   3326,
#   361,
#   612,
#   2071,
#   1067,
#   101,
#   94,
#   3618,
#   0,
#   624,
#   47,
#   1417,
#   0,
#   51,
#   2795,
#   1882,
#   27],
#  [286, 82, 1827, 18, 82, 0, 61, 0, 0, 0, 1009, 88],
#  [46, 582, 206, 0],
#  [4083, 0],
#  [39],
#  [84, 0],
#  [11, 0, 183],
#  [1481, 0, 176, 983, 0],
#  [4337, 17, 5, 483, 234, 668, 0],
#  [0, 0, 254, 10, 69, 265, 244, 0, 0, 114, 49, 1062],
#  [1005, 765, 651, 355, 35, 2310, 523, 1461, 3231, 136],
#  [420, 169, 2789, 0, 244, 334, 161, 5, 0, 40],
#  [24, 3370],
#  [4164, 738, 0, 69, 296, 3371, 1557, 19, 3127, 0],
#  [231, 1651, 52, 892, 4, 0, 63],
#  [0, 384, 148, 2056, 124, 836, 0],
#  [642, 655, 2109, 4235, 36, 2381, 1258, 37, 116, 3498, 83, 135, 127, 4965],
#  [280, 199, 190, 1941, 16, 190, 0, 0, 271],
#  [67, 569, 0],
#  [0, 665, 3081, 4742, 1104],
#  [0, 4, 19, 65, 2727, 875, 66, 0, 248, 0, 132, 393, 344, 999, 3546],
#  [101, 0, 0, 110],
#  [0, 446, 501, 1349, 0],
#  [0, 591, 167, 4165, 0, 27, 1569, 209, 123, 123, 858, 51, 826, 1336, 28, 0],
#  [383, 2437, 562, 179, 1330, 349, 3770, 4975, 0, 0, 0, 1195, 3841],
#  [897,
#   302,
#   435,
#   251,
#   0,
#   18,
#   84,
#   94,
#   0,
#   77,
#   1541,
#   2139,
#   13,
#   1921,
#   542,
#   0,
#   291,
#   146,
#   880,
#   9,
#   328,
#   2464,
#   185,
#   182,
#   405,
#   0,
#   0,
#   2289,
#   29,
#   435,
#   417,
#   0],
#  [15, 25, 1605, 4004, 4856, 0, 313, 687, 1212, 0],
#  [59, 1787, 0, 0, 0, 78, 0],
#  [50,
#   158,
#   305,
#   0,
#   0,
#   0,
#   0,
#   183,
#   0,
#   505,
#   1105,
#   0,
#   389,
#   0,
#   1091,
#   19,
#   0,
#   1403,
#   263,
#   263,
#   9,
#   2,
#   1662,
#   1386],
#  [0,
#   3243,
#   0,
#   0,
#   313,
#   16,
#   921,
#   0,
#   660,
#   18,
#   826,
#   130,
#   0,
#   0,
#   278,
#   26,
#   149,
#   511,
#   200,
#   5,
#   0,
#   4857,
#   2796,
#   387,
#   32,
#   1180,
#   0,
#   530,
#   170,
#   1922,
#   34,
#   2557,
#   80],
#  [2676, 3043, 259, 1448, 540, 0, 0],
#  [285, 57, 36, 2003, 101, 2057, 136],
#  [87, 0, 2021, 253, 0, 1362, 0, 1362, 0, 0],
#  [20, 713, 7, 636],
#  [13, 1632, 0, 499],
#  [658, 185, 0, 0, 102, 75, 3919],
#  [1976, 206, 3499],
#  [546, 3001, 0, 148, 229, 132],
#  [0, 2593, 0, 790, 1633, 733],
#  [15, 36, 710, 1203, 699, 140, 394],
#  [0, 4858, 0, 94],
#  [1039, 702, 2595, 230, 332, 96],
#  [0, 0, 0, 1428, 0, 0, 0, 0, 0, 22, 914, 0, 288, 0, 0, 0, 0, 3692, 95, 0, 0],
#  [12,
#   44,
#   7,
#   17,
#   30,
#   111,
#   185,
#   4545,
#   4650,
#   92,
#   400,
#   2485,
#   671,
#   0,
#   665,
#   0,
#   0,
#   90,
#   29,
#   2485,
#   546,
#   1752,
#   0,
#   2558,
#   1285,
#   511,
#   121,
#   284,
#   231,
#   121,
#   0,
#   9,
#   2,
#   0],
#  [4, 0, 6],
#  [954,
#   1268,
#   788,
#   0,
#   0,
#   0,
#   172,
#   2508,
#   70,
#   0,
#   935,
#   0,
#   4975,
#   0,
#   2681,
#   33,
#   3481,
#   2486,
#   293,
#   116,
#   255,
#   0,
#   0,
#   445,
#   3183,
#   301,
#   279,
#   1838,
#   0,
#   0],
#  [506, 506, 0, 506, 1914, 1675, 1304, 103, 4549, 540, 87, 633, 2081, 648, 437],
#  [374, 197, 5, 2423, 8],
#  [14, 0, 4],
#  [23],
#  [0, 4244, 1804, 486, 4976, 1206, 5, 656, 241, 0, 780, 0, 0, 0, 4837, 0],
#  [4433, 44, 323],
#  [249, 1092, 3327],
#  [576, 49, 1482, 5],
#  [4, 6],
#  [106, 1344, 0, 154],
#  [0, 17, 33, 1432, 0],
#  [997],
#  [625, 118, 218, 2947, 0, 447, 984, 0, 0],
#  [108, 282, 14, 3144, 551, 73, 1046],
#  [0, 673, 199, 0, 0, 0, 200, 0, 0, 222, 23, 0, 0, 19],
#  [0, 1532],
#  [1233, 824, 0],
#  [82, 306, 57, 1625, 11, 4443],
#  [1883, 2058],
#  [4166, 0, 13, 1233, 2824, 1040, 547, 22, 338, 519, 0, 542, 0],
#  [38, 26, 38, 22, 941, 68, 837, 790],
#  [1705, 0, 238, 107, 390, 390, 78, 0, 116, 293, 4731, 45, 260],
#  [82, 57, 0],
#  [299, 2256, 54, 276, 443, 32, 614],
#  [0, 4245, 0, 3239, 0, 154],
#  [430, 1708, 0, 0, 432, 267, 318, 1625, 13, 1525],
#  [485, 0, 140, 394],
#  [260, 0, 0, 1085, 53, 3090, 3696, 0, 0, 45, 131, 268],
#  [625, 339],
#  [555, 0],
#  [12, 4078, 336],
#  [85, 246],
#  [290, 0, 0, 0, 636],
#  [910, 697, 64, 1442, 72, 460, 0, 220],
#  [107, 4749, 973, 3619, 0, 0, 1462, 3619, 665, 0, 0],
#  [41,
#   67,
#   41,
#   439,
#   13,
#   77,
#   1041,
#   1056,
#   1297,
#   358,
#   559,
#   1245,
#   1112,
#   808,
#   0,
#   0,
#   0,
#   616,
#   0,
#   131,
#   1578,
#   124,
#   506,
#   0,
#   2230,
#   0,
#   0,
#   1479,
#   0,
#   0,
#   511,
#   4438,
#   86,
#   0,
#   124,
#   445,
#   0],
#  [295, 1733, 0, 3617, 171, 346, 0, 817, 26, 275, 32, 3927, 121, 640, 5, 3235],
#  [413, 0, 652, 327, 1942],
#  [3433, 4533, 2948, 2137, 181, 5, 1499, 83, 118, 181, 2184, 0],
#  [233, 1769, 0, 3852, 0, 3287, 3928, 110],
#  [0, 0, 150, 0],
#  [0,
#   11,
#   1437,
#   32,
#   1826,
#   0,
#   175,
#   168,
#   172,
#   43,
#   4550,
#   83,
#   210,
#   1980,
#   3372,
#   292,
#   506,
#   243,
#   3,
#   0,
#   969],
#  [1857, 2, 1634, 13, 15],
#  [178, 189, 2637, 457, 169, 783, 565, 18, 2359, 234, 567, 0, 217, 1355, 290],
#  [3, 0, 1753, 317],
#  [0, 208, 14, 266, 42],
#  [480, 1046],
#  [0],
#  [0, 0, 78, 34, 139, 0, 103],
#  [926, 247, 291, 580, 2211],
#  [0, 71, 0, 64, 4167, 12, 465, 863, 483, 597, 628],
#  [126, 782, 328, 39, 497],
#  [0, 137],
#  [0, 2401, 36, 1439, 622, 2797],
#  [834, 177, 508, 5, 860, 267, 318, 0, 0, 187, 789],
#  [2904, 62, 1954, 0, 85, 4, 1458, 0, 1923, 0, 0, 1943, 0, 1449],
#  [0, 2311, 2311, 0],
#  [0, 0, 4246, 296, 4859, 160],
#  [1597, 4, 275],
#  [288, 0, 2258],
#  [1287, 0, 0, 17, 2116, 4977],
#  [2052, 47, 5, 76, 76, 497],
#  [726],
#  [41, 1369, 2, 621, 456, 9, 343, 164, 29],
#  [0],
#  [672, 8],
#  [177, 55, 553, 1795, 0, 34, 139, 3620, 900, 0, 699],
#  [117, 18, 34, 139, 149, 144, 214],
#  [0, 169, 587, 0, 45, 2022, 16, 75, 662, 1451, 1451, 3500, 1578, 0, 334],
#  [2825, 2541],
#  [45, 1314, 6, 5, 296, 2, 83, 43, 106, 0],
#  [310, 66, 0, 86, 0, 0, 965, 26, 0, 0, 28],
#  [579,
#   497,
#   0,
#   2039,
#   1709,
#   0,
#   0,
#   1353,
#   0,
#   129,
#   106,
#   0,
#   0,
#   1259,
#   2939,
#   199,
#   791,
#   1770,
#   7],
#  [319, 18, 411, 142, 21, 0, 985, 1463, 0, 0, 4084, 114, 49, 256, 6],
#  [304, 0, 462, 0, 805, 2, 805, 37, 805, 305, 955],
#  [117, 1470, 13, 210, 12, 1260],
#  [254],
#  [611, 0, 0, 4854],
#  [0, 0],
#  [1804, 667],
#  [4750, 540, 99, 3145, 0],
#  [3373, 1613, 4],
#  [0, 348, 3028, 181, 0, 0],
#  [26, 2824, 15, 1196, 70, 2185, 563, 715, 1570],
#  [0, 0, 3493, 635, 0],
#  [2404, 0, 2040],
#  [258, 2529],
#  [0, 269, 0, 317],
#  [4085, 1331, 1769, 80, 0, 1369, 29, 0, 1610],
#  [2504, 503, 2899, 49, 0, 0, 0, 13, 376, 901, 1243, 2504, 194, 979, 0],
#  [2679, 121, 0, 86, 144, 388, 24, 3621, 0],
#  [371, 3423, 187, 678, 0, 0, 756],
#  [3556, 1006, 0, 290, 28],
#  [0, 3493, 0, 0],
#  [0, 36, 147, 724, 0, 0, 0, 151, 289, 0, 1195, 0, 0, 1319, 901, 60],
#  [50, 2728, 0, 1853, 2, 473, 152],
#  [101, 84, 16, 84, 87, 237, 0],
#  [2729, 143, 137, 28],
#  [299, 3853, 2487, 823, 10, 111],
#  [125, 2360, 209, 1403],
#  [12, 558, 122, 632, 716, 0, 29],
#  [0, 0, 16, 650, 259],
#  [0, 3616, 467, 356],
#  [1425, 452, 92, 0, 35, 0, 39, 188, 620, 74, 15],
#  [7,
#   582,
#   1975,
#   407,
#   22,
#   283,
#   128,
#   962,
#   4642,
#   1246,
#   128,
#   0,
#   0,
#   401,
#   652,
#   1522,
#   761,
#   521,
#   401,
#   0,
#   3288,
#   3622,
#   0,
#   368,
#   0,
#   368,
#   283,
#   31,
#   204,
#   521,
#   4168,
#   0,
#   270],
#  [0, 0, 687, 3854, 0, 0, 3289, 699, 1735, 890, 10, 2077],
#  [12, 1277, 29],
#  [0, 1422, 0, 0, 532, 0],
#  [0, 0, 0, 5, 0, 1180, 9, 2, 41, 1098, 33, 2905, 210, 1483, 21, 17, 6, 1261],
#  [733, 44, 11, 4741, 85],
#  [0, 156, 180, 2004, 151, 2637, 457, 921, 0, 0, 0],
#  [2161],
#  [2481, 260, 19, 0, 624],
#  [1159, 0],
#  [413, 13, 266],
#  [3775, 1582, 0, 1998, 74, 24, 484, 13, 60, 800, 800, 14, 277],
#  [7, 0, 894],
#  [242, 0, 992, 533, 849, 780, 1568, 0, 4751, 0, 1568, 2096],
#  [0, 1302, 1298, 359],
#  [500, 1499, 149, 0, 0],
#  [4860, 1249, 21, 78],
#  [898,
#   3290,
#   95,
#   0,
#   200,
#   550,
#   0,
#   0,
#   1707,
#   124,
#   0,
#   63,
#   258,
#   0,
#   447,
#   3855,
#   1155,
#   157,
#   0,
#   0,
#   0,
#   72,
#   0,
#   0,
#   364,
#   150,
#   20,
#   182,
#   4752,
#   398,
#   0,
#   1327,
#   147,
#   0,
#   41,
#   0],
#  [2178, 0, 1980, 228, 0, 1543, 752, 592, 0],
#  [127, 0, 2798, 19, 876, 1635, 360, 2005, 0, 130, 0],
#  [1782, 0, 0],
#  [924],
#  [975, 67, 527, 388, 1117, 80, 1105, 101, 0],
#  [945, 2003],
#  [1659,
#   1329,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2438,
#   603,
#   278,
#   14,
#   0,
#   0,
#   471,
#   0,
#   1955,
#   0,
#   154,
#   4338,
#   45,
#   4968,
#   45],
#  [68, 845, 0],
#  [0, 0, 480, 150, 0],
#  [0, 1636, 183, 0, 2638, 0, 134, 292, 4005],
#  [29, 374],
#  [4551, 1924, 4552, 0, 4, 0, 3244, 0, 1939, 0, 288, 0, 2151, 109, 0],
#  [37, 94, 679, 1158, 0],
#  [364, 1571, 1805, 862, 1395, 0],
#  [0, 965, 58, 437, 26, 167, 3044, 152],
#  [66,
#   630,
#   1720,
#   1499,
#   1288,
#   767,
#   0,
#   242,
#   53,
#   495,
#   0,
#   252,
#   362,
#   664,
#   34,
#   155,
#   118,
#   835,
#   51,
#   0,
#   662],
#  [5, 1636, 112, 877, 626, 2285, 3776, 6, 4086, 19],
#  [33, 3557, 46, 93],
#  [1259, 0, 3481, 19, 85, 160, 4339],
#  [956, 4075, 0, 257, 86, 15],
#  [1884,
#   589,
#   0,
#   3856,
#   0,
#   37,
#   308,
#   2762,
#   4978,
#   0,
#   469,
#   864,
#   2691,
#   165,
#   0,
#   825,
#   421,
#   447,
#   10,
#   75,
#   220,
#   2690],
#  [22, 0, 23],
#  [784, 0, 0, 757, 333, 99, 4],
#  [157, 125, 631, 899, 1221],
#  [1544,
#   4006,
#   757,
#   132,
#   568,
#   240,
#   3486,
#   1981,
#   32,
#   361,
#   441,
#   1495,
#   263,
#   4753,
#   485,
#   0,
#   0,
#   0],
#  [981, 151, 558],
#  [3434, 0, 3683, 4340, 0],
#  [2140, 265],
#  [0, 1723, 3, 0],
#  [0, 9, 0, 175, 200, 175, 691, 0, 3002, 314, 0, 3697, 234, 567],
#  [80,
#   33,
#   3433,
#   87,
#   0,
#   4861,
#   1016,
#   3,
#   3245,
#   1136,
#   0,
#   1289,
#   1016,
#   16,
#   0,
#   1735,
#   890,
#   34,
#   12,
#   0,
#   0,
#   558,
#   1016,
#   1425,
#   1903,
#   134,
#   3558,
#   389,
#   720,
#   0,
#   11,
#   3433,
#   87,
#   0],
#  ...]

# %%
maximum_length = max(list(map(len,encoded)))

# %%
len(encoded)
# Out:
# 149995

# %%
maximum_length
# Out:
# 67
